# %%
import re
import requests
import json

from pprint import pprint
from bs4 import BeautifulSoup

# %%
url = 'https://onefootball.com/pt-br/match/2269972'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

# %%
resp = requests.get(url, headers=headers)

# %%
resp
# Out:
# <Response [200]>

# %%
data = resp.text

data
# Out:
# '<!DOCTYPE html><html class="no-js" data-revision="23bb1cbbae21-prod" lang="pt-br" data-theme="auto"><head>\n  <meta charset="utf-8">\n  <title>Barcelona Feminino vs Real Madrid Feminino + “resultados”</title>\n  <base href="/">\n  <link href="https://api.onefootball.com" rel="preconnect">\n  <link href="https://image-service.onefootball.com" rel="preconnect">\n  <link href="https://oneftbl-cms.imgix.net" rel="preconnect">\n  <link href="https://pappagallu.onefootball.com" rel="preconnect">\n  <link href="https://web.localytics.com" rel="preconnect">\n  <link href="https://webanalytics.localytics.com" rel="preconnect">\n  <link href="/assets/images/favicon/manifest.json" rel="manifest">\n\n  <meta content="width=device-width, initial-scale=1" name="viewport">\n\n  <meta content="#fff" name="theme-color">\n  <meta content="light dark" name="color-scheme">\n  <link href="/assets/images/favicon/favicon.svg?20200629" rel="icon">\n  <link color="#1A1A24" href="/assets/images/favicon/favic
# ...

# %%
soup = BeautifulSoup(resp.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-revision="23bb1cbbae21-prod" data-theme="auto" lang="pt-br"><head>
# <meta charset="utf-8"/>
# <title>Barcelona Feminino vs Real Madrid Feminino + “resultados”</title>
# <base href="/"/>
# <link href="https://api.onefootball.com" rel="preconnect"/>
# <link href="https://image-service.onefootball.com" rel="preconnect"/>
# <link href="https://oneftbl-cms.imgix.net" rel="preconnect"/>
# <link href="https://pappagallu.onefootball.com" rel="preconnect"/>
# <link href="https://web.localytics.com" rel="preconnect"/>
# <link href="https://webanalytics.localytics.com" rel="preconnect"/>
# <link href="/assets/images/favicon/manifest.json" rel="manifest"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="#fff" name="theme-color"/>
# <meta content="light dark" name="color-scheme"/>
# <link href="/assets/images/favicon/favicon.svg?20200629" rel="icon"/>
# ...

# %%
soup.findAll('div', attrs={'class': re.compile('match-lineup-v2__player')})
# Out:
# [<div class="match-lineup-v2__player" title="Claudia Pina"><of-image class="match-lineup-v2__player-photo-wrapper"><div class="of-image" style="--padding-bottom-mobile:100%;--padding-bottom-tablet-portrait:100%;--padding-bottom-tablet-landscape:100%;--padding-bottom-desktop:100%;"><picture class="of-image__picture"><source media="(min-width: 1280px)" srcset="https://image-service.onefootball.com/transform?w=48&amp;h=48&amp;dpr=2&amp;image=https%253A%252F%252Fimages.onefootball.com%252Fplayers%252F180%252F346897.jpg"><source media="(min-width: 1024px) and (max-width: 1279px)" srcset="https://image-service.onefootball.com/transform?w=48&amp;h=48&amp;dpr=2&amp;image=https%253A%252F%252Fimages.onefootball.com%252Fplayers%252F180%252F346897.jpg"><source media="(min-width: 768px) and (max-width: 1023px)" srcset="https://image-service.onefootball.com/transform?w=48&amp;h=48&amp;dpr=2&amp;image=https%253A%252F%252Fimages.onefootball.com%252Fplayers%252F180%252F346897.jpg"><img alt="Claudia P
# ...

# %%
for tag in soup.findAll('span', attrs={'class': re.compile('match-lineup-v2__player-name')}):
    print(tag.text)
# Out:
#  6. Pina Medina
#  10. Hermoso
#  7. Graham Hansen
#  11. Putellas
#  12. Guijarro
#  14. Bonmatí
#  16. Rolfo
#  4. León
#  2. Paredes
#  8. Torrejón
#  1. Paños

# %%
results = soup.findAll('section', attrs={'class': re.compile('resultsContainer')})

# %%
def has_data_src(tag):
    return tag.has_attr('data-src')

# %%
for tag in results:
    if 'data-src' in tag.attrs:
        print(tag)

# %%
# 10 competitions are displayed on the page
len(results)
# Out:
# 10

# %%
for competition in results:
    for tag in competition:
        print(type(tag))
        print(tag)
        print('hump')
    break
# Out:
# <class 'bs4.element.NavigableString'>
#
#
# hump
# <class 'bs4.element.Tag'>
# <div class="games-header" data-league="primera-division-women">
# <a class="v-flags__link" href="/football/leagues/spain">
# <img alt="Espanha" class="lazy img expand-list__img img--size-s" data-src="https://sportcdns.live/resized/72/72/category/56760aeeaa0c103030709a7ba43262e431bc2b44d5d53a4b165f1973f3749e50.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# </a>
# <a class="games-cat" href="/football/leagues/spain">
# Espanha
# </a>
# <a class="games-slug" href="/football/leagues/spain/primera-division-women">
# Primeira Divisão
# </a>
# <span class="games-total">1</span>
# <button class="games-toggle"></button>
# </div>
# hump
# <class 'bs4.element.NavigableString'>
#
#
# hump
# <class 'bs4.element.Tag'>
# <div class="game" data-game-date="1648893600" data-game-id="610c80976d92df505b618192" data-tournament-id="5c9dfcf399bab86aec4aa713">
# <span class="game-info">
# ...

# %%
results
# Out:
# [<section class="games resultsContainer" data-league="primera-division-women" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <div class="games-header" data-league="primera-division-women">
#  <a class="v-flags__link" href="/football/leagues/spain">
#  <img alt="Espanha" class="lazy img expand-list__img img--size-s" data-src="https://sportcdns.live/resized/72/72/category/56760aeeaa0c103030709a7ba43262e431bc2b44d5d53a4b165f1973f3749e50.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
#  </a>
#  <a class="games-cat" href="/football/leagues/spain">
#  Espanha
#  </a>
#  <a class="games-slug" href="/football/leagues/spain/primera-division-women">
#  Primeira Divisão
#  </a>
#  <span class="games-total">1</span>
#  <button class="games-toggle"></button>
#  </div>
#  <div class="game" data-game-date="1648893600" data-game-id="610c80976d92df505b618192" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
# ...
