# %%
import time
from selenium import webdriver
from pprint import pprint
from bs4 import BeautifulSoup
import re
import pandas as pd
import time

# %%
from OnefootballScrap import ScrapAllMatches

# %%
primeira_divisao_teams = [
        # 'Barcelona Feminino',
        # 'Atlético de Madrid Feminino',
        # 'Real Madrid Feminino',
        # 'Deportivo Alavés Feminino',
        # 'Real Sociedad Feminino',
        # 'Athletic Bilbao Feminino',
        # 'Madrid CFF',
        # 'Rayo Valhecano Feminino',
        # 'Servilha Feminino',
        'Villareal Feminino',
        'Eibar Feminino',
        'Levante Feminino',
        'Real Betis Feminino',
        'Universidade Cajasol Trigueros',
        'UDG Tenerife',
        'Valência Feminino']

df_primeira_divisao = pd.DataFrame()

# %%
for team in primeira_divisao_teams:
    ScrapAllMatches.get_all_team_matches(team)
# Out:
# Procurando o time:  Villareal Feminino
# Team found:  Villarreal Feminino
# https://onefootball.com/pt-br/time/villarreal-feminino-19942
# Partidas encontradas:  28
# https://onefootball.com/pt-br/match/2243608
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:359: UserWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   warnings.warn("find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead")
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:341: UserWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   warnings.warn("find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead")
# https://onefootball.com/pt-br/match/2243605
# ...
