# %%
import time
from selenium import webdriver
from pprint import pprint
from bs4 import BeautifulSoup
import re

# %%
match_url = 'https://onefootball.com/pt-br/match/2272922'

# %%
def get_teams(list_of_elements):
    teams = {
        'home_team': list_of_elements[0].text,
        'away_team': list_of_elements[1].text,
    }
    return teams

def get_score(list_of_elements):
    score_element = list_of_elements[0].text.split('\n')
    scores = {
        'home_team_score': score_element[0],
        'away_team_score': score_element[2]
    }
    return scores

def get_events(list_of_elements):
    events_list = []
    for event in list_of_elements:
        event_type = event.find_element_by_tag_name('img').get_attribute('alt')
        event_text = event.text.split('\n')
        event_time = event_text[0]
        print(re.findall(r'\d+', event_time))
        player_1 = event_text[1]
        if len(event_text) >= 3:
            player_2 = event_text[2]
        else:
            player_2 = ''
        event_detail = {
            'time': int(re.findall(r'\d+', event_time)[0]) if len(re.findall(r'\d+', event_time)) else event_time,
            'player_1': player_1,
            'player_2': player_2,
            'event': event_type
        }
        events_list.append(event_detail)
    return events_list

def get_stats(list_of_elements):
    stats_list = []
    for stat in list_of_elements:
        stats_text = stat.text.split('\n')
        home_team_stat = stats_text[0]
        stat_name = stats_text[1]
        away_team_stat = stats_text[2]
        stats_detail = {
            'home_team_stat': home_team_stat,
            'away_team_stat': away_team_stat,
            'stat_name': stat_name
        }
        stats_list.append(stats_detail)
    return stats_list

def get_infos(list_of_elements):
    infos_list = []
    for info in list_of_elements:
        info_text = info.text.split('\n')
        info_title = info_text[0]
        info_content = info_text[1]
        info_detail = {
            'info_title': info_title,
            'info_content': info_content,
        }
        infos_list.append(info_detail)
    return infos_list

# %%
def get_all_match_information(match_url):
    driver = webdriver.Chrome('chromedriver.exe')  # Optional argument, if not specified will search path.
    driver.get(match_url)
    
    # Aceitar cookies:
    cookies = driver.find_elements_by_xpath("//button[contains(@aria-label, 'Agree to our data processing and close')]")
    if len(cookies):
        cookies[0].click()
    else:
        pprint('No cookies message displayed!')
    
    # Quem está jogando:
    search = driver.find_elements_by_xpath("//of-match-score-team")
    teams = get_teams(search)
    
    # Placar:
    search = driver.find_elements_by_xpath("//p[contains(@class, 'match-score-scores')]")
    score = get_score(search)
    
    # Escalação dos times:
    html = driver.page_source
    soup = BeautifulSoup(html, "lxml")
    
    home_team = []
    for tag in soup.findAll('span', attrs={'class': re.compile('match-lineup-v2__player-name')}):
        home_team.append(tag.text)
        
    search_box = driver.find_elements_by_xpath("//button[contains(@title, '" + teams['away_team'] + "')]")
    html = driver.page_source
    soup = BeautifulSoup(html, "lxml")
    
    away_team = []
    for tag in soup.findAll('span', attrs={'class': re.compile('match-lineup-v2__player-name')}):
        away_team.append(tag.text)
        
    # Expandir a lista de eventos:
    events_expand = driver.find_elements_by_xpath("//button[contains(@class, 'match-events__toggle-button')]")
    if len(events_expand):
        events_expand[0].click()
        
    # Eventos:
    events_tags = driver.find_elements_by_xpath("//li[contains(@class, 'match-events__item')]")
    events = get_events(events_tags)
    
    # Estatísticas:
    stats_tags = driver.find_elements_by_xpath("//li[contains(@class, 'match-stats__list-item')]")
    stats = get_stats(stats_tags)
    
    # Informações da partida:
    general_infos = driver.find_elements_by_xpath("//li[contains(@class, 'match-info__entry')]")
    infos = get_infos(general_infos)
    
    pprint('Teams:')
    pprint(teams)
    
    pprint('Score:')
    pprint(score)
    
    pprint('Home team:')
    pprint(home_team)
    
    pprint('Away team:')
    pprint(away_team)
    
    pprint('Events:')
    pprint(events)
    
    pprint('Stats:')
    pprint(stats)
    
    pprint('Infos:')
    pprint(infos)
    
    return teams, score, home_team, away_team, events, stats, infos

# %%
get_all_match_information(match_url)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28140\2088708976.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')  # Optional argument, if not specified will search path.
# C:\Users\user\AppData\Local\Temp\ipykernel_28140\2088708976.py:6: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   cookies = driver.find_elements_by_xpath("//button[contains(@aria-label, 'Agree to our data processing and close')]")
# C:\Users\user\AppData\Local\Temp\ipykernel_28140\2088708976.py:13: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   search = driver.find_elements_by_xpath("//of-match-score-team")
# C:\Users\user\AppData\Local\Temp\ipykernel_28140\2088708976.py:17: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   search = driver.find_elements_by_xpath("//p[contains(@class, 'match-score-scores')]")
# C:\Users\user\AppData\Local\Temp\ipykernel_28140\2088708976.py:28: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   search_box = driver.find_elements_by_xpath("//button[contains(@title, '" + teams['away_team'] + "')]")
# C:\Users\user\AppData\Local\Temp\ipykernel_28140\2088708976.py:37: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   events_expand = driver.find_elements_by_xpath("//button[contains(@class, 'match-events__toggle-button')]")
# C:\Users\user\AppData\Local\Temp\ipykernel_28140\2088708976.py:42: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   events_tags = driver.find_elements_by_xpath("//li[contains(@class, 'match-events__item')]")
# ['46']
# ['46']
# ['50']
# ['64']
# ['64']
# ['70']
# ['70']
# ['79']
# ['86']
# ['88']
# ['90']
# ['90']
# ['105']
# ['121']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# 'Teams:'
# {'away_team': 'Villarreal Feminino', 'home_team': 'CDEF Logrono'}
# 'Score:'
# {'away_team_score': '0', 'home_team_score': '0'}
# 'Home team:'
# [' 9. Garcia ',
#  ' 17. Martínez Pérez ',
#  ' 14. Aby ',
#  ' 6. Moreno Beleño ',
#  ' 21. Solow ',
#  ' 26. Sánchez Durán ',
#  ' 20. Valderas Martínez ',
#  ' 25. Masferrer Cruz ',
#  ' 3. Infante ',
#  ' 5. Palacios Marí ',
#  ' 1. Longa Bescos ']
# 'Away team:'
# [' 9. Garcia ',
#  ' 17. Martínez Pérez ',
#  ' 14. Aby ',
#  ' 6. Moreno Beleño ',
#  ' 21. Solow ',
#  ' 26. Sánchez Durán ',
#  ' 20. Valderas Martínez ',
#  ' 25. Masferrer Cruz ',
#  ' 3. Infante ',
#  ' 5. Palacios Marí ',
#  ' 1. Longa Bescos ']
# 'Events:'
# [{'event': 'Substituição',
#   'player_1': 'Teresa Morató',
#   'player_2': 'Aixa García',
#   'time': 46},
#  {'event': 'Substituição',
#   'player_1': 'Fatou Coulibaly',
#   'player_2': 'Andrea Palacios',
#   'time': 46},
#  {'event': 'Cartão amarelo',
#   'player_1': 'Teresa Morató',
#   'player_2': '',
#   'time': 50},
#  {'event': 'Substituição',
#   'player_1': 'Ana Hernández',
#   'player_2': 'Olga Garcia',
#   'time': 64},
#  {'event': 'Substituição',
#   'player_1': 'Moa Öhman',
#   'player_2': 'Madison Solow',
#   'time': 64},
#  {'event': 'Substituição',
#   'player_1': 'Zaira Flores',
#   'player_2': 'Cienfu',
#   'time': 70},
#  {'event': 'Substituição',
#   'player_1': 'Sara Medina',
#   'player_2': 'Raquel Pinel',
#   'time': 70},
#  {'event': 'Substituição',
#   'player_1': 'Ida Guehai',
#   'player_2': 'Elena Martínez',
#   'time': 79},
#  {'event': 'Substituição',
#   'player_1': 'Sara Bermell',
#   'player_2': 'Belén',
#   'time': 86},
#  {'event': 'Substituição',
#   'player_1': 'Rebecca Elloh',
#   'player_2': 'Lourdes Moreno',
#   'time': 88},
#  {'event': 'Cartão vermelho',
#   'player_1': 'Player 0',
#   'player_2': '',
#   'time': 90},
#  {'event': 'Substituição',
#   'player_1': 'Laura Royo',
#   'player_2': 'Lara Mata',
#   'time': 90},
#  {'event': 'Substituição',
#   'player_1': 'Salma Paralluelo',
#   'player_2': 'Estefa',
#   'time': 105},
#  {'event': 'Cartão amarelo',
#   'player_1': 'Laura Royo',
#   'player_2': '',
#   'time': 121},
#  {'event': 'Gol',
#   'player_1': 'Yenifer Giménez',
#   'player_2': 'Gol 0 - 1',
#   'time': 'Pen'},
#  {'event': 'Gol',
#   'player_1': 'Ana Hernández',
#   'player_2': 'Gol 1 - 1',
#   'time': 'Pen'},
#  {'event': 'Gol',
#   'player_1': 'Sara Medina',
#   'player_2': 'Gol 1 - 2',
#   'time': 'Pen'},
#  {'event': 'Gol',
#   'player_1': 'Ida Guehai',
#   'player_2': 'Gol 2 - 2',
#   'time': 'Pen'},
#  {'event': 'Gol',
#   'player_1': 'Zaira Flores',
#   'player_2': 'Gol 2 - 3',
#   'time': 'Pen'},
#  {'event': 'Gol',
#   'player_1': 'Jessica Aby',
#   'player_2': 'Gol 3 - 3',
#   'time': 'Pen'},
#  {'event': 'Falhou',
#   'player_1': 'Salma Paralluelo',
#   'player_2': 'Falhou 3 - 3',
#   'time': 'Pen'},
#  {'event': 'Falhou',
#   'player_1': 'Rebecca Elloh',
#   'player_2': 'Falhou 3 - 3',
#   'time': 'Pen'},
#  {'event': 'Gol',
#   'player_1': 'Teresa Morató',
#   'player_2': 'Gol 3 - 4',
#   'time': 'Pen'},
#  {'event': 'Gol',
#   'player_1': 'Lorena Valderas',
#   'player_2': 'Gol 4 - 4',
#   'time': 'Pen'},
#  {'event': 'Gol',
#   'player_1': 'Laura Royo',
#   'player_2': 'Gol 4 - 5',
#   'time': 'Pen'},
#  {'event': 'Falhou',
#   'player_1': 'Raquel Infante',
#   'player_2': 'Falhou 4 - 5',
#   'time': 'Pen'}]
# 'Stats:'
# []
# 'Infos:'
# [{'info_content': 'Copa de la Reina', 'info_title': 'Competição'},
#  {'info_content': '26/01/22', 'info_title': 'Início'},
#  {'info_content': 'Estadio Mundial 82', 'info_title': 'Estádio'}]
# C:\Users\user\AppData\Local\Temp\ipykernel_28140\2088708976.py:46: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stats_tags = driver.find_elements_by_xpath("//li[contains(@class, 'match-stats__list-item')]")
# C:\Users\user\AppData\Local\Temp\ipykernel_28140\2088708976.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   general_infos = driver.find_elements_by_xpath("//li[contains(@class, 'match-info__entry')]")
# ({'home_team': 'CDEF Logrono', 'away_team': 'Villarreal Feminino'},
#  {'home_team_score': '0', 'away_team_score': '0'},
#  [' 9. Garcia ',
#   ' 17. Martínez Pérez ',
#   ' 14. Aby ',
#   ' 6. Moreno Beleño ',
#   ' 21. Solow ',
#   ' 26. Sánchez Durán ',
#   ' 20. Valderas Martínez ',
#   ' 25. Masferrer Cruz ',
#   ' 3. Infante ',
#   ' 5. Palacios Marí ',
#   ' 1. Longa Bescos '],
#  [' 9. Garcia ',
#   ' 17. Martínez Pérez ',
#   ' 14. Aby ',
#   ' 6. Moreno Beleño ',
#   ' 21. Solow ',
#   ' 26. Sánchez Durán ',
#   ' 20. Valderas Martínez ',
#   ' 25. Masferrer Cruz ',
#   ' 3. Infante ',
#   ' 5. Palacios Marí ',
#   ' 1. Longa Bescos '],
#  [{'time': 46,
#    'player_1': 'Teresa Morató',
#    'player_2': 'Aixa García',
#    'event': 'Substituição'},
#   {'time': 46,
#    'player_1': 'Fatou Coulibaly',
#    'player_2': 'Andrea Palacios',
#    'event': 'Substituição'},
#   {'time': 50,
#    'player_1': 'Teresa Morató',
#    'player_2': '',
#    'event': 'Cartão amarelo'},
#   {'time': 64,
#    'player_1': 'Ana Hernández',
#    'player_2': 'Olga Garcia',
#    'event': 'Substituição'},
#   {'time': 64,
#    'player_1': 'Moa Öhman',
#    'player_2': 'Madison Solow',
#    'event': 'Substituição'},
#   {'time': 70,
#    'player_1': 'Zaira Flores',
#    'player_2': 'Cienfu',
#    'event': 'Substituição'},
#   {'time': 70,
#    'player_1': 'Sara Medina',
#    'player_2': 'Raquel Pinel',
#    'event': 'Substituição'},
#   {'time': 79,
#    'player_1': 'Ida Guehai',
#    'player_2': 'Elena Martínez',
#    'event': 'Substituição'},
#   {'time': 86,
#    'player_1': 'Sara Bermell',
#    'player_2': 'Belén',
#    'event': 'Substituição'},
#   {'time': 88,
#    'player_1': 'Rebecca Elloh',
#    'player_2': 'Lourdes Moreno',
#    'event': 'Substituição'},
#   {'time': 90,
#    'player_1': 'Player 0',
#    'player_2': '',
#    'event': 'Cartão vermelho'},
#   {'time': 90,
#    'player_1': 'Laura Royo',
#    'player_2': 'Lara Mata',
#    'event': 'Substituição'},
#   {'time': 105,
#    'player_1': 'Salma Paralluelo',
#    'player_2': 'Estefa',
#    'event': 'Substituição'},
#   {'time': 121,
#    'player_1': 'Laura Royo',
#    'player_2': '',
#    'event': 'Cartão amarelo'},
#   {'time': 'Pen',
#    'player_1': 'Yenifer Giménez',
#    'player_2': 'Gol 0 - 1',
#    'event': 'Gol'},
#   {'time': 'Pen',
#    'player_1': 'Ana Hernández',
#    'player_2': 'Gol 1 - 1',
#    'event': 'Gol'},
#   {'time': 'Pen',
#    'player_1': 'Sara Medina',
#    'player_2': 'Gol 1 - 2',
#    'event': 'Gol'},
#   {'time': 'Pen',
#    'player_1': 'Ida Guehai',
#    'player_2': 'Gol 2 - 2',
#    'event': 'Gol'},
#   {'time': 'Pen',
#    'player_1': 'Zaira Flores',
#    'player_2': 'Gol 2 - 3',
#    'event': 'Gol'},
#   {'time': 'Pen',
#    'player_1': 'Jessica Aby',
#    'player_2': 'Gol 3 - 3',
#    'event': 'Gol'},
#   {'time': 'Pen',
#    'player_1': 'Salma Paralluelo',
#    'player_2': 'Falhou 3 - 3',
#    'event': 'Falhou'},
#   {'time': 'Pen',
#    'player_1': 'Rebecca Elloh',
#    'player_2': 'Falhou 3 - 3',
#    'event': 'Falhou'},
#   {'time': 'Pen',
#    'player_1': 'Teresa Morató',
#    'player_2': 'Gol 3 - 4',
#    'event': 'Gol'},
#   {'time': 'Pen',
#    'player_1': 'Lorena Valderas',
#    'player_2': 'Gol 4 - 4',
#    'event': 'Gol'},
#   {'time': 'Pen',
#    'player_1': 'Laura Royo',
#    'player_2': 'Gol 4 - 5',
#    'event': 'Gol'},
#   {'time': 'Pen',
#    'player_1': 'Raquel Infante',
#    'player_2': 'Falhou 4 - 5',
#    'event': 'Falhou'}],
#  [],
#  [{'info_title': 'Competição', 'info_content': 'Copa de la Reina'},
#   {'info_title': 'Início', 'info_content': '26/01/22'},
#   {'info_title': 'Estádio', 'info_content': 'Estadio Mundial 82'}])

# %%
score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <module>
# ----> 1 score
#
# NameError: name 'score' is not defined

# %%
search = driver.find_elements_by_xpath("//p[contains(@class, 'match-score-scores')]")
score = get_score(search)

# %%
driver = webdriver.Chrome('chromedriver.exe')  # Optional argument, if not specified will search path.
driver.get(match_url)

# Aceitar cookies:
cookies = driver.find_elements_by_xpath("//button[contains(@aria-label, 'Agree to our data processing and close')]")
if len(cookies):
    cookies[0].click()
else:
    pprint('No cookies message displayed!')

# %%
search = driver.find_elements_by_xpath("//span[contains(text(), 'Adiado')]")

# %%
search
