# %%
import time
from selenium import webdriver
from pprint import pprint
from bs4 import BeautifulSoup
import re
import pandas as pd
import time

# %%
from OnefootballScrap import ScrapAllMatches

# %%
team_name = 'Barcelona'

# %%
df = ScrapAllMatches.get_all_team_matches(team_name)
# Out:
# 'No cookies message displayed!'
# Team found:  FC Barcelona
# https://onefootball.com/pt-br/time/fc-barcelona-5
# Partidas encontradas:  43
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:359: UserWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   warnings.warn("find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead")
# 'No cookies message displayed!'
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:341: UserWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   warnings.warn("find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead")
# 'No cookies message displayed!'
# 'No cookies message displayed!'
# 'No cookies message displayed!'
# ...

# %%
df
# Out:
#    match_date           home_team           away_team home_team_score  \
# 0    03/04/22        FC Barcelona             Sevilla               1
# 1    20/03/22         Real Madrid        FC Barcelona               0
# 2    17/03/22         Galatasaray        FC Barcelona               1
# 3    13/03/22        FC Barcelona          CA Osasuna               4
# 4    10/03/22        FC Barcelona         Galatasaray               0
# 5    06/03/22               Elche        FC Barcelona               1
# 6    27/02/22        FC Barcelona     Athletic Bilbao               4
# 7    24/02/22              Napoli        FC Barcelona               2
# 8    20/02/22            Valencia        FC Barcelona               1
# 9    17/02/22        FC Barcelona              Napoli               1
# 10   13/02/22            Espanyol        FC Barcelona               2
# 11   06/02/22        FC Barcelona  Atlético de Madrid               4
# ...
