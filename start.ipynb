# %%
import re
import requests
import json

from pprint import pprint
from bs4 import BeautifulSoup

# %%
url = 'https://azscore.com.br/football/team/fc-barcelona-1/scores'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

# %%
resp = requests.get(url, headers=headers)

# %%
resp
# Out:
# <Response [200]>

# %%
data = resp.text

data
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<script async data-cfasync=\'false\' src="//cdn.bescore.com/libs/e.js"></script>\n<script data-cfasync=\'false\'>\r\n(function(w,r){\r\nw[r]=w[r]||function(){(w[r+\'l\']=w[r+\'l\']||[]).push(arguments)};\r\n})(window,\'ABNS\');\r\n</script>\n<script data-ad-client="ca-pub-1829773294117843" async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js" type="6afa614c93024545cb6f87ea-text/javascript"></script>\n<script data-cfasync=\'false\'>var partnerIds = {\'xbet\':\'305297\',\'bet365\':\'365_00941764\',\'xstavka\':\'510251\',\'bet9ja\':\'151437\',\'22bet\':\'655039\'}</script>\n\n<script type="6afa614c93024545cb6f87ea-text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\r\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\r\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\r\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\r\n})(window,document,\'script\',\'dataLayer\',\'GTM-TSN384Q\');</script>\n\n<link rel="dns-prefetch" href="//www.google.com" />\n<link rel="dns-prefetch" href="//www.google-analytics.com" />\n<link rel="dns-prefetch" href="//www.googletagmanager.com" />\n<link rel="dns-prefetch" href="//pagead2.googlesyndication.com" />\n<link rel="dns-prefetch" href="//adservice.google.com/">\n<link rel="dns-prefetch" href="//googleads.g.doubleclick.net">\n<link rel="dns-prefetch" href="//www.googletagservices.com">\n<link rel="dns-prefetch" href="//tpc.googlesyndication.com">\n<link rel="dns-prefetch" href="//cdn.bescore.com" />\n<link rel="dns-prefetch" href="//z.cdn.bescore.com" />\n<link rel="preload" href="https://cdn.bescore.com/libs/e.js" as="script" />\n<link rel="preload" href="https://www.google-analytics.com/analytics.js" as="script" />\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge"><script type="6afa614c93024545cb6f87ea-text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.eu01.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-2cbb0d1fc536d8d929f",applicationID:"57231449"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n,r){return function(){return s.recordSupportability("API/"+e+"/called"),o(t+e,[u.now()].concat(c(arguments)),n?null:this,r),n?void 0:this}}var o=t("handle"),a=t(10),c=t(11),f=t("ee").get("tracer"),u=t("loader"),s=t(4),d=NREUM;"undefined"==typeof window.newrelic&&(newrelic=d);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",v=l+"ixn-";a(p,function(t,e){d[e]=i(l,e,!0,"api")}),d.addPageAction=i(l,"addPageAction",!0),d.setCurrentRouteName=i(l,"routeName",!0),e.exports=newrelic,d.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(v+"tracer",[u.now(),t,n],r),function(){if(f.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw f.emit("fn-err",[arguments,this,t],n),t}finally{f.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(v,e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),s.recordSupportability("API/noticeError/called"),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){var r=!1;try{var i=Object.defineProperty({},"passive",{get:function(){r=!0}});wind ...

# %%
soup = BeautifulSoup(resp.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <script async="" data-cfasync="false" src="//cdn.bescore.com/libs/e.js"></script>
# <script data-cfasync="false">
# (function(w,r){
# w[r]=w[r]||function(){(w[r+'l']=w[r+'l']||[]).push(arguments)};
# })(window,'ABNS');
# </script>
# <script async="" data-ad-client="ca-pub-1829773294117843" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js" type="6afa614c93024545cb6f87ea-text/javascript"></script>
# <script data-cfasync="false">var partnerIds = {'xbet':'305297','bet365':'365_00941764','xstavka':'510251','bet9ja':'151437','22bet':'655039'}</script>
# <script type="6afa614c93024545cb6f87ea-text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-TSN384Q');</script>
# <link href="//www.google.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//adservice.google.com/" rel="dns-prefetch"/>
# <link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//www.googletagservices.com" rel="dns-prefetch"/>
# <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//cdn.bescore.com" rel="dns-prefetch"/>
# <link href="//z.cdn.bescore.com" rel="dns-prefetch"/>
# <link as="script" href="https://cdn.bescore.com/libs/e.js" rel="preload"/>
# <link as="script" href="https://www.google-analytics.com/analytics.js" rel="preload"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/><script type="6afa614c93024545cb6f87ea-text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.eu01.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-2cbb0d1fc536d8d929f",applicationID:"57231449"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n,r){return function(){return s.recordSupportability("API/"+e+"/called"),o(t+e,[u.now()].concat(c(arguments)),n?null:this,r),n?void 0:this}}var o=t("handle"),a=t(10),c=t(11),f=t("ee").get("tracer"),u=t("loader"),s=t(4),d=NREUM;"undefined"==typeof window.newrelic&&(newrelic=d);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",v=l+"ixn-";a(p,function(t,e){d[e]=i(l,e,!0,"api")}),d.addPageAction=i(l,"addPageAction",!0),d.setCurrentRouteName=i(l,"routeName",!0),e.exports=newrelic,d.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(v+"tracer",[u.now(),t,n],r),function(){if(f.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw f.emit("fn-err",[arguments,this,t],n),t}finally{f.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(v,e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),s.recordSupportability("API/noticeError/called"),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){var r=!1;try{var i=Object.defineProperty({},"passive",{get:function(){r=!0}});window.addEventListener("testPassive",null,i),window.removeEventListener("testPassive",null,i)}catch(o){}e.exports=function(t){return r?{passive:!0,capture:!!t}:!!t}},{}],4:[function(t,e,n){function r(t,e){var n=[a,t,{name:t},e];return o("storeMetric",n,null,"api"),n}function i(t,e){var n=[c,t,{name:t},e];return o("storeEventMetrics",n,null,"api"),n}var o=t("handle"),a="sm",c="cm";e.exports={constants:{SUPPORTABILITY_METRIC:a,CUSTOM_METRIC:c},recordSupportability:r,recordCustom:i}},{}],5:[function(t,e,n){function r(){return c.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,c=t(12);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],6:[function(t,e,n){function r(t){return!(!t||!t.protocol||"file:"===t.protocol)}e.exports=r},{}],7:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?l("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&l("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();if(n.length>0){var r=n[n.length-1];if(u&&u<r.startTime)return;var i=[r],o=a({});o&&i.push(o),l("lcp",i)}}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||l("cls",[t])})}function a(t){var e=navigator.connection||navigator.mozConnection||navigator.webkitConnection;if(e)return e.type&&(t["net-type"]=e.type),e.effectiveType&&(t["net-etype"]=e.effectiveType),e.rtt&&(t["net-rtt"]=e.rtt),e.downlink&&(t["net-dlink"]=e.downlink),t}function c(t){if(t instanceof y&&!w){var e=Math.round(t.timeStamp),n={type:t.type};a(n),e<=v.now()?n.fid=v.now()-e:e>v.offset&&e<=Date.now()?(e-=v.offset,n.fid=v.now()-e):e=v.now(),w=!0,l("timing",["fi",e,n])}}function f(t){"hidden"===t&&(u=v.now(),l("pageHide",[u]))}if(!("init"in NREUM&&"page_view_timing"in NREUM.i ...
# <meta content="width=device-width,initial-scale=1.0, maximum-scale=1.0,user-scalable=no" name="viewport"/>
# <link href="/az-favicon.ico" rel="icon"/>
# <link crossorigin="" href="https://fonts.gstatic.com/" rel="preconnect"/>
# <title>
#                Resultado do jogo do Barcelona (Feminino) de hoje      </title>
# <meta content="" name="keywords"/>
# <meta content="     Resultado do jogo do Barcelona (Feminino) de hoje ➦ Resultados dos jogo de ontem ᐉ azscore.com.br." name="description"/>
# <link as="font" crossorigin="anonymous" href="/build/fonts/icomoon.ttf" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="/build/fonts/roboto-300.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="/build/fonts/roboto-regular.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="/build/fonts/roboto-500.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="/build/fonts/roboto-700.woff2" rel="preload"/>
# <link href="https://azscore.com.br/football/team/fc-barcelona-1/scores" rel="canonical"/>
# <link href="https://azscore.com.br/football/team/fc-barcelona-1/scores" hreflang="pt-BR" rel="alternate"/> <link href="https://fscore.org.uk/football/team/fc-barcelona-1/scores" hreflang="en-GB" rel="alternate"/> <link href="https://azscore.co.it/football/team/fc-barcelona-1/scores" hreflang="it-IT" rel="alternate"/> <link href="https://azscore.es/football/team/fc-barcelona-1/scores" hreflang="es-ES" rel="alternate"/> <link href="https://azscore.fr/football/team/fc-barcelona-1/scores" hreflang="fr-FR" rel="alternate"/> <link href="https://azscore.ru/football/team/fc-barcelona-1/scores" hreflang="ru-RU" rel="alternate"/> <link href="https://azscore.com/football/team/fc-barcelona-1/scores" hreflang="en" rel="alternate"/> <link href="https://azscore.com/el/football/team/fc-barcelona-1/scores" hreflang="el-GR" rel="alternate"/> <link href="https://azscore.com/nl/football/team/fc-barcelona-1/scores" hreflang="nl-NL" rel="alternate"/> <link href="https://azscore.com/ro/football/team/fc-barcelona-1/scores" hreflang="ro-RO" rel="alternate"/> <link href="https://azscore.com/ge/football/team/fc-barcelona-1/scores" hreflang="ka-GE" rel="alternate"/> <link href="https://azscore.mx/football/team/fc-barcelona-1/scores" hreflang="es-MX" rel="alternate"/> <link href="https://azscore.de/football/team/fc-barcelona-1/scores" hreflang="de-DE" rel="alternate"/> <link href="https://azscore-th.com/football/team/fc-barcelona-1/scores" hreflang="th-TH" rel="alternate"/> <link href="https://azscore-kr.com/football/team/fc-barcelona-1/scores" hreflang="ko-KR" rel="alternate"/> <link href="https://azscore.id/football/team/fc-barcelona-1/scores" hreflang="id-ID" rel="alternate"/> <link href="https://azscore.uz/football/team/fc-barcelona-1/scores" hreflang="uz-UZ" rel="alternate"/> <link href="https://canliskor.biz.tr/football/team/fc-barcelona-1/scores" hreflang="tr-TR" rel="alternate"/> <link href="https://azscore.pl/football/team/fc-barcelona-1/scores" hreflang="pl-PL" rel="alternate"/> <link href="https://azscore-am.com/football/team/fc-barcelona-1/scores" hreflang="hy-AM" rel="alternate"/> <link href="https://azscore.co.za/football/team/fc-barcelona-1/scores" hreflang="en-ZA" rel="alternate"/>
# <script type="application/ld+json">
# [
#                                                                                     {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Barcelona (Feminino) - Villarreal CF",
# "startDate": "2022-04-02T07:00:00-03:00",
# "url": "https://azscore.com.br/football/game/fc-barcelona-villarreal-cf-2022-04-03",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Barcelona (Feminino) - Villarreal CF: Primeira Divisão",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Barcelona (Feminino) - Real Madrid (Feminino)",
# "startDate": "2022-03-30T13:45:00-03:00",
# "url": "https://azscore.com.br/football/game/fc-barcelona-real-madrid-2022-03-30",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Barcelona (Feminino) - Real Madrid (Feminino): Liga dos Campeões UEFA, Feminino",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Europa",
#     "address": "Europa"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Madrid (feminino) - Barcelona (Feminino)",
# "startDate": "2022-03-26T08:00:00-03:00",
# "url": "https://azscore.com.br/football/game/madrid-ccf-fc-barcelona-2022-03-27",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Madrid (feminino) - Barcelona (Feminino): Primeira Divisão",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Real Madrid (Feminino) - Barcelona (Feminino)",
# "startDate": "2022-03-22T17:00:00-03:00",
# "url": "https://azscore.com.br/football/game/real-madrid-fc-barcelona-2022-03-22",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Real Madrid (Feminino) - Barcelona (Feminino): Liga dos Campeões UEFA, Feminino",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Europa",
#     "address": "Europa"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Real Sociedad (Feminino) - Barcelona (Feminino)",
# "startDate": "2022-03-16T16:45:00-03:00",
# "url": "https://azscore.com.br/football/game/real-sociedad-san-sebastian-fc-barcelona-2022-03-16",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Real Sociedad (Feminino) - Barcelona (Feminino): Taça de SM La Reina",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Barcelona (Feminino) - Real Madrid (Feminino)",
# "startDate": "2022-03-13T08:00:00-03:00",
# "url": "https://azscore.com.br/football/game/fc-barcelona-real-madrid-2022-03-13",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Barcelona (Feminino) - Real Madrid (Feminino): Primeira Divisão",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Deportivo Alaves (Feminino) - Barcelona (Feminino)",
# "startDate": "2022-03-06T08:00:00-03:00",
# "url": "https://azscore.com.br/football/game/deportivo-alaves-fc-barcelona-2022-03-06",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Deportivo Alaves (Feminino) - Barcelona (Feminino): Primeira Divisão",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Rayo Vallecano (Feminino) - Barcelona (Feminino)",
# "startDate": "2022-03-02T12:00:00-03:00",
# "url": "https://azscore.com.br/football/game/rayo-vallecano-fc-barcelona-2022-03-02",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Rayo Vallecano (Feminino) - Barcelona (Feminino): Taça de SM La Reina",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Athletic Bilbao (Feminino) - Barcelona (Feminino)",
# "startDate": "2022-02-13T08:00:00-03:00",
# "url": "https://azscore.com.br/football/game/athletic-bilbao-fc-barcelona-2022-02-13",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Athletic Bilbao (Feminino) - Barcelona (Feminino): Primeira Divisão",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Real Sociedad (Feminino) - Barcelona (Feminino)",
# "startDate": "2022-02-09T13:00:00-03:00",
# "url": "https://azscore.com.br/football/game/real-sociedad-san-sebastian-fc-barcelona-2022-02-09",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Real Sociedad (Feminino) - Barcelona (Feminino): Primeira Divisão",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Barcelona (Feminino) - Eibar (Feminino)",
# "startDate": "2022-02-06T08:00:00-03:00",
# "url": "https://azscore.com.br/football/game/fc-barcelona-sd-eibar-2022-02-06",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Barcelona (Feminino) - Eibar (Feminino): Primeira Divisão",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Levante (Feminino) - Barcelona (Feminino)",
# "startDate": "2022-02-02T13:00:00-03:00",
# "url": "https://azscore.com.br/football/game/levante-ud-fc-barcelona-2022-02-02",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Levante (Feminino) - Barcelona (Feminino): Primeira Divisão",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Barcelona (Feminino) - Real Betis (Feminino)",
# "startDate": "2022-01-30T07:00:00-03:00",
# "url": "https://azscore.com.br/football/game/barcelona-women-real-betis-women-2022-01-30",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Barcelona (Feminino) - Real Betis (Feminino): Primeira Divisão",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Barcelona (Feminino) - Real Betis (Feminino)",
# "startDate": "2022-01-29T08:00:00-03:00",
# "url": "https://azscore.com.br/football/game/fc-barcelona-real-betis-sevilla-2022-01-30",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Barcelona (Feminino) - Real Betis (Feminino): Primeira Divisão",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Barcelona (Feminino) - Atlético de Madrid (Feminino)",
# "startDate": "2022-01-23T08:00:00-03:00",
# "url": "https://azscore.com.br/football/game/fc-barcelona-atletico-madrid-2022-01-23",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Barcelona (Feminino) - Atlético de Madrid (Feminino): Supertaça de Espanha, Feminino",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Barcelona (Feminino) - Real Madrid (Feminino)",
# "startDate": "2022-01-19T15:15:00-03:00",
# "url": "https://azscore.com.br/football/game/fc-barcelona-real-madrid-2022-01-19",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Barcelona (Feminino) - Real Madrid (Feminino): Supertaça de Espanha, Feminino",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Barcelona (Feminino) - Sporting de Huelva (Feminino)",
# "startDate": "2022-01-12T13:00:00-03:00",
# "url": "https://azscore.com.br/football/game/fc-barcelona-sporting-de-huelva-2022-01-12",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Barcelona (Feminino) - Sporting de Huelva (Feminino): Primeira Divisão",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 UD Granadilla Tenerife Sur (Feminino) - Barcelona (Feminino)",
# "startDate": "2022-01-08T13:00:00-03:00",
# "url": "https://azscore.com.br/football/game/udg-tenerife-fc-barcelona-2022-01-09",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "UD Granadilla Tenerife Sur (Feminino) - Barcelona (Feminino): Primeira Divisão",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Barcelona (Feminino) - Madrid (feminino)",
# "startDate": "2021-12-22T13:00:00-03:00",
# "url": "https://azscore.com.br/football/game/fc-barcelona-madrid-ccf-2021-12-22",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Barcelona (Feminino) - Madrid (feminino): Primeira Divisão",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                         ,                                                    {
# "@context": "http://schema.org/",
# "@type": "SportsEvent",
# "name": "󾟛 Barcelona (Feminino) - Rayo Vallecano (Feminino)",
# "startDate": "2021-12-18T08:00:00-03:00",
# "url": "https://azscore.com.br/football/game/fc-barcelona-rayo-vallecano-2021-12-19",
# "organizer": {
#     "@type": "SportsOrganization",
#     "name": "Barcelona (Feminino) - Rayo Vallecano (Feminino): Primeira Divisão",
#     "sport": "football"
#     },
# "location": {
#     "@type": "Country",
#     "name": "Espanha",
#     "address": "Espanha"
#     }
# }
#
#
#                                                                         ]
#     </script>
# <link as="style" href="/build/critical-desktop-css.3c092b0b.css" rel="preload"/>
# <link href="/build/critical-desktop-css.3c092b0b.css" rel="stylesheet"/>
# <link as="style" href="/build/desktopCss.c7cf2d17.css" rel="preload"/>
# <link href="/build/desktopCss.c7cf2d17.css" rel="stylesheet"/>
# <script async="" src="/cdn-cgi/bm/cv/669835187/api.js"></script></head>
# <body class="page-team add-catfish" data-sport="football">
# <div id="root-identity-element"></div>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TSN384Q&amp;nojscript=true" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div data-pops="" id="1433115542"></div>
# <script type="6afa614c93024545cb6f87ea-text/javascript">
# (function(w,d,r){
#     w[r]=w[r]||function(){(w[r+'l']=w[r+'l']||[]).push(arguments)};
#     var bonus = d.querySelector('.v-bonus');
#     var id = '1904601112';
#     if (bonus) {
#         bonus.id = id;
#         w[r](id,{id: id})
#     }
# })(window,document,'ABNS');
# </script>
# <div id="app">
# <div class="window-slot">
# <a data-br-bg="" id="1900449903"></a>
# </div>
# <ul class="noti noti--cta" data-icon="cookie" id="cookie-noti">
# <li class="noti__item">
# <div class="noti__content">
# <p>Nós usamos cookies. Ao navegar em nosso site, você aceita nossa política de cookies.
# <a href="/policy" target="_blank">Política de cookies de privacidade</a> </p>
# <button class="noti__cta primary">Entendi</button>
# </div>
# </li>
# </ul>
# <header class="header">
# <div class="container">
# <div class="calendar">
# <div class="calendar__container" data-domain="azscore.com.br" data-sport="football" id="calendar__container" locale="pt"></div>
# <div class="calendar__footer">
# <a class="today-matches__link" href="https://azscore.com.br/">
# <span class="today-matches__title">Resultados de hoje</span>
# <span class="today-matches__icon"></span>
# </a></div>
# </div>
# <div>
# <a class="header__logo" href="https://azscore.com.br/">
# <img alt="logo" class="header__logo-img" height="34" src="/build/img/site-logo.5d8215cd.svg" width="134"/>
# <span class="logo-after">
# <img alt="br" class="logo-after__img" height="34" src="https://sportcdns.live/resized/11/11/country-flags/br.png" width="134"/>
# <span class="logo-after__title">BR</span>
# </span>
# </a>
# </div>
# <nav class="header-nav">
# <ul class="header-nav__list">
# <li class="header-nav__item active" data-new-item-text="New">
# <a class="header-nav__link" href="https://azscore.com.br/">Futebol</a>
# </li>
# <li class="header-nav__item" data-new-item-text="New">
# <a class="header-nav__link" href="https://azscore.com.br/basketball">Basquetebol</a>
# </li>
# <li class="header-nav__item">
# <a class="header-nav__link" href="https://azscore.com.br/bookmakers">Casas de apostas</a>
# </li>
# <li class="header-nav__item new">
# <a class="header-nav__link" href="https://azscore.com.br/betsy" rel="nofollow">
# Apostas Desportivas </a>
# </li>
# </ul>
# </nav>
# <button class="toggle-calendar"></button>
# </div>
# </header>
# <div class="main-menu__container">
# <nav class="main-menu">
# <a class="logo" data-icon="football">
# <span class="logo__text">Futebol</span> </a>
# <a class="main-menu__link" href="/">
# <span class="main-menu__title">Hoje</span>
# </a>
# <a class="main-menu__link" href="/live">
# <span class="main-menu__title">Online</span>
# <span class="main-menu__total">123</span>
# </a>
# <a class="main-menu__link" href="/yesterday">
# <span class="main-menu__title">Ontem</span>
# </a>
# <a class="main-menu__link" href="/tomorrow"><span class="main-menu__title">Amanhã</span>
# </a>
# <a class="main-menu__link" href="/odds"><span class="main-menu__title">Coeficientes</span>
# </a>
# <a class="main-menu__link" href="/predictions"><span class="main-menu__title">Previsões</span>
# </a>
# <a class="main-menu__link" href="/football/leagues"><span class="main-menu__title">Base de dados</span>
# </a>
# <a class="main-menu__link" href="/football/my-games">
# <span class="main-menu__title">Meus jogos</span>
# <span class="main-menu__total" id="countMyGames">0</span>
# </a>
# </nav>
# </div>
# <div class="bn bn-slot--top">
# <div data-s="" id="1249511619"></div>
# </div>
# <div class="main-container">
# <aside class="aside-left">
# <div class="bn bn-slot--left">
# <div data-s="" id="1862354768"></div>
# </div>
# </aside>
# <main>
# <div class="container center-content-holder">
# <section class="section--left">
# <span class="list-title list-title--black list-title--dots list-title--grow list-title--size-16 list-title--bold">TOP Torneios</span>
# <div class="top-leagues">
# <a class="league" data-league="brasileiro-serie-a" href="/football/leagues/brazil/brasileiro-serie-a">
# <img alt="Brasileirão Série A" class="lazy" data-src="https://sportcdns.live/resized/72/72/tournament/df2154d4b915d51ae0adbf5360c88c89b3507ea6692c6ab5b8952e1d4b55d3d4.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# <p class="league-name">Brasileirão Série A</p>
# <p class="league-country">Brasil</p>
# </a>
# <a class="league" data-league="copa-libertadores" href="/football/leagues/south-america/copa-libertadores">
# <img alt="Copa Libertadores" class="lazy" data-src="https://sportcdns.live/resized/72/72/tournament/115a50d6104ffe32473269f6e98ce9a60ba3b6487ab27c6007f78c2cea64bdf2.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# <p class="league-name">Copa Libertadores</p>
# <p class="league-country">América do Sul</p>
# </a>
# <a class="league" data-league="copa-sudamericana" href="/football/leagues/south-america/copa-sudamericana">
# <img alt="Taça Sul-Americana" class="lazy" data-src="https://sportcdns.live/resized/72/72/tournament/e283a2f75afa7147c54d1a3466b8f59a9497b5ecdd92287b08243117707ab2d0.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# <p class="league-name">Taça Sul-Americana</p>
# <p class="league-country">América do Sul</p>
# </a>
# <a class="league" data-league="uefa-champions-league" href="/football/leagues/europe/uefa-champions-league">
# <img alt="Liga dos Campeões da UEFA" class="lazy" data-src="https://sportcdns.live/resized/72/72/tournament/d552f48bd902ce7011790b3d271388049516eba81f7075b4fce4210ee8759720.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# <p class="league-name">Liga dos Campeões da UEFA</p>
# <p class="league-country">Europa</p>
# </a>
# <a class="league" data-league="uefa-europa-league" href="/football/leagues/europe/uefa-europa-league">
# <img alt="Liga Europa UEFA" class="lazy" data-src="https://sportcdns.live/resized/72/72/tournament/7ac865ca1badfa43a3ffe86f16d4b42767a6c8507cd8215ca2d36c796a933bd3.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# <p class="league-name">Liga Europa UEFA</p>
# <p class="league-country">Europa</p>
# </a>
# <a class="league" data-league="premier-league" href="/football/leagues/england/premier-league">
# <img alt="Premier League" class="lazy" data-src="https://sportcdns.live/resized/72/72/tournament/f45c5e6178441e2369617f85d0a6388ed3341fd7fb66f693e278adedf6bb1a13.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# <p class="league-name">Premier League</p>
# <p class="league-country">Inglaterra</p>
# </a>
# <a class="league" data-league="laliga" href="/football/leagues/spain/laliga">
# <img alt="La Liga" class="lazy" data-src="https://sportcdns.live/resized/72/72/tournament/66f2cb28b81815323c4ef9177775b4b9e6b48dbc0bf2b6799b079a6d2cf72fef.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# <p class="league-name">La Liga</p>
# <p class="league-country">Espanha</p>
# </a>
# <a class="league" data-league="bundesliga-1" href="/football/leagues/germany/bundesliga-1">
# <img alt="Bundesliga" class="lazy" data-src="https://sportcdns.live/resized/72/72/tournament/d0c6d998c69326e7bce0153720c7eca718d340e1e48f79f58755be45f4d8fe9d.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# <p class="league-name">Bundesliga</p>
# <p class="league-country">Alemanha</p>
# </a>
# <a class="league" data-league="serie-a" href="/football/leagues/italy/serie-a">
# <img alt="Série A" class="lazy" data-src="https://sportcdns.live/resized/72/72/tournament/9a5927eafc91dd5651ab7eb5a76d39c48c6eff1f03b5e6e9867bae258256d69b.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# <p class="league-name">Série A</p>
# <p class="league-country">Itália</p>
# </a>
# <a class="league" data-league="ligue-1" href="/football/leagues/france/ligue-1">
# <img alt="Ligue 1" class="lazy" data-src="https://sportcdns.live/resized/72/72/tournament/b9d166ba4b1e463c968f992734ab5d9ac2e0a30946d120eab27ce9e3fb1d6323.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# <p class="league-name">Ligue 1</p>
# <p class="league-country">França</p>
# </a>
# <a class="league" data-league="copa-america" href="/football/leagues/south-america/copa-america">
# <img alt="Copa America" class="lazy" data-src="https://sportcdns.live/resized/72/72/tournament/15da4f08afa428725c509aef457baeb158256ca22d4d2c96ff2b117660aeb64c.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# <p class="league-name">Copa America</p>
# <p class="league-country">América do Sul</p>
# </a>
# <a class="league" data-league="wc-qual-conmebol" href="/football/leagues/south-america/wc-qual-conmebol">
# <img alt="Campeonato do Mundo, Qualificação CONMEBOL" class="lazy" data-src="https://sportcdns.live/resized/72/72/tournament/6b61b15365584c2c3935ffa4de7088ab27e3b6bc06b2951b47d9305683759830.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# <p class="league-name">Campeonato do Mundo, Qualificação CONMEBOL</p>
# <p class="league-country">América do Sul</p>
# </a>
# </div>
# <ul class="countries-list" id="countries-list">
# <li class="countries-list__header">
# <span class="list-title list-title--black list-title--dots list-title--grow list-title--size-16 list-title--bold">Todos os países</span>
# <a class="see-all__link" data-action="add-countries">Ver tudo</a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/afghanistan">
# <img alt="Afeganistão" class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/bb234d72f72ec9388172a67495ddac0e354f0faef8cfd951f1caa3c0b99a73cc.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">Afeganistão</span>
# </a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/south-africa">
# <img alt="África do Sul" class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/b6c27b47960b351cac81ec2548b6c88011802df6427770288a5cc7c296585e3b.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">África do Sul</span>
# <span class="countries-list__info">
# <span class="countries-list__count countries-list__count--red">0</span>
# <span class="countries-list__count-separator">/</span>
# <span class="countries-list__count">10</span>
# </span>
# </a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/albania">
# <img alt="Albânia" class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/0182b77e99c2fc10de2cb4b78999e09c5b90132345758e0580742d7a3ae7b233.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">Albânia</span>
# <span class="countries-list__info">
# <span class="countries-list__count countries-list__count--red">0</span>
# <span class="countries-list__count-separator">/</span>
# <span class="countries-list__count">8</span>
# </span>
# </a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/germany">
# <img alt="Alemanha" class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/e8d8c65526e5c069f9df6a997caeadf8bdad6fd7f1c6dd5c97bb63df0f195317.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">Alemanha</span>
# <span class="countries-list__info">
# <span class="countries-list__count countries-list__count--red">23</span>
# <span class="countries-list__count-separator">/</span>
# <span class="countries-list__count">54</span>
# </span>
# </a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/andorra">
# <img alt="Andorra" class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/5a44a27faa0354a146c0e616a5ee8d2a29edfdbce075d5b3862347c0b031fa3d.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">Andorra</span>
# <span class="countries-list__info">
# <span class="countries-list__count countries-list__count--red">0</span>
# <span class="countries-list__count-separator">/</span>
# <span class="countries-list__count">2</span>
# </span>
# </a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/angola">
# <img alt="Angola" class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/964ef4e8b7ae627da260b24a3347d17eafee1d55e9dff5836852c6c8b0b05f68.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">Angola</span>
# <span class="countries-list__info">
# <span class="countries-list__count countries-list__count--red">0</span>
# <span class="countries-list__count-separator">/</span>
# <span class="countries-list__count">1</span>
# </span>
# </a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/saudi-arabia">
# <img alt="Arábia Saudita" class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/788c8e1fa2178ccbbedd724ad52a1186cf0c9804d5b067fd200e8377ebbbbdff.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">Arábia Saudita</span>
# </a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/algeria">
# <img alt="Argélia" class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/4d1610c228bb1a16935551ab2922775c9019920f6eee5e5434e7487139459849.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">Argélia</span>
# </a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/argentina">
# <img alt="Argentina" class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/1bf5a1b69efc52425736fb440b72a12f952d1732275f7ffa1b7b077f6d64d8ae.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">Argentina</span>
# <span class="countries-list__info">
# <span class="countries-list__count countries-list__count--red">1</span>
# <span class="countries-list__count-separator">/</span>
# <span class="countries-list__count">21</span>
# </span>
# </a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/armenia">
# <img alt="Arménia" class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/3f3de494c9e9e4c5175da26a0d8aa147d3596cafef7c3996f29f680a23740cd2.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">Arménia</span>
# <span class="countries-list__info">
# <span class="countries-list__count countries-list__count--red">0</span>
# <span class="countries-list__count-separator">/</span>
# <span class="countries-list__count">2</span>
# </span>
# </a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/aruba">
# <img alt="Aruba " class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/197c9766ea75e475c578c6a20e1d595a0c54e1c0972feeced23de7f6fcbf2312.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">Aruba </span>
# <span class="countries-list__info">
# <span class="countries-list__count countries-list__count--red">0</span>
# <span class="countries-list__count-separator">/</span>
# <span class="countries-list__count">1</span>
# </span>
# </a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/australia">
# <img alt="Austrália" class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/40fd8d3bbd0cb67d1d3c033b730884e118badaf9213206283e7917b06ff9020b.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">Austrália</span>
# <span class="countries-list__info">
# <span class="countries-list__count countries-list__count--red">0</span>
# <span class="countries-list__count-separator">/</span>
# <span class="countries-list__count">105</span>
# </span>
# </a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/austria">
# <img alt="Áustria" class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/fd6cd1603189a65a32e2711585dfb01f3a2097796c1831824298a05f36c93220.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">Áustria</span>
# <span class="countries-list__info">
# <span class="countries-list__count countries-list__count--red">2</span>
# <span class="countries-list__count-separator">/</span>
# <span class="countries-list__count">21</span>
# </span>
# </a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/azerbaijan">
# <img alt="Azerbaijão" class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/5ec10dbfd538927e6d1e1b2f5fa4927dab5b82271e1f4378c9bac053adab960a.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">Azerbaijão</span>
# <span class="countries-list__info">
# <span class="countries-list__count countries-list__count--red">1</span>
# <span class="countries-list__count-separator">/</span>
# <span class="countries-list__count">2</span>
# </span>
# </a>
# </li>
# <li class="countries-list__item">
# <a class="countries-list__link countries-list__expand" data-route="/football/more-leagues/bahrain">
# <img alt="Bahrain" class="lazy img countries-list__img img--size-s" data-src="https://sportcdns.live/resized/20/20/category/dc2e1ceb64ff4d544581241eba71c756453165edf19d6c1ab571540d6785d318.png" height="20" src="data:image/svg+xml;base64,..." width="20"/>
# <span class="countries-list__title">Bahrain</span>
# <span class="countries-list__info">
# <span class="countries-list__count countries-list__count--red">0</span>
# <span class="countries-list__count-separator">/</span>
# <span class="countries-list__count">1</span>
# </span>
# </a>
# </li>
# </ul>
# <a class="show-more__button" data-action="add-countries" id="showAllCountries">Ver tudo<span class="show-more__arrow"></span></a>
# <div class="bn bn-slot--left-center">
# <div data-b="" id="1561928358"></div>
# </div>
# </section>
# <section class="section--center">
# <div class="content">
# <ul class="breadcrumbs">
# <li class="breadcrumbs__next">
# <a class="breadcrumbs__link" href="https://azscore.com.br/">
# Futebol
# </a>
# <span class="breadcrumbs__arrow"></span>
# </li>
# <li class="breadcrumbs__next">
# <a class="breadcrumbs__link" href="https://azscore.com.br/football/leagues/spain">
# Espanha
# </a>
# <span class="breadcrumbs__arrow"></span>
# </li>
# <li class="breadcrumbs__next">
# <h1 class="last">
# Barcelona (Feminino) Partitura
# </h1>
# </li>
# </ul>
# <div class="league-card" data-team="fc-barcelona-1">
# <div class="league-card__avatar">
# <img alt="Barcelona (Feminino)" class="lazy img img--size-xxl" data-src="https://sportcdns.live/resized/224/224/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="224" src="data:image/svg+xml;base64,..." width="224"/>
# </div>
# <div class="league-card__columns">
# <span class="list-title list-title--black list-title--size-20">Barcelona (Feminino)</span>
# <a class="league-card__command" href="/football/leagues/spain">
# <img alt="Espanha" class="lazy img img--rounded img--size-sm" data-src="https://sportcdns.live/resized/40/40/category/56760aeeaa0c103030709a7ba43262e431bc2b44d5d53a4b165f1973f3749e50.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
# <h6 class="list-title list-title--gray list-title--size-14">Espanha</h6>
# </a>
# </div>
# </div>
# <div class="tab-menu__container">
# <ul class="tab-menu" data-show-arrows="">
# <li class="tab-menu__item">
# <a class="tab-menu__link" href="/football/team/fc-barcelona-1">Visão geral
# </a>
# </li>
# <li class="tab-menu__item">
# <a class="tab-menu__link active" href="/football/team/fc-barcelona-1/scores">Partitura
# </a>
# </li>
# <li class="tab-menu__item">
# <a class="tab-menu__link" href="/football/team/fc-barcelona-1/fixtures">Próximos jogos
# </a>
# </li>
# <li class="tab-menu__item">
# <a class="tab-menu__link" href="/football/team/fc-barcelona-1/lineup">Jogadoras</a>
# </li>
# </ul>
# </div>
# <h2 class="section-title">Barcelona (Feminino) Último resultado</h2>
# <div id="gamesWrapper">
# <section class="games resultsContainer" data-league="primera-division-women" data-tournament-id="5c9dfcf399bab86aec4aa713">
# <div class="games-header" data-league="primera-division-women">
# <a class="v-flags__link" href="/football/leagues/spain">
# <img alt="Espanha" class="lazy img expand-list__img img--size-s" data-src="https://sportcdns.live/resized/72/72/category/56760aeeaa0c103030709a7ba43262e431bc2b44d5d53a4b165f1973f3749e50.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# </a>
# <a class="games-cat" href="/football/leagues/spain">
# Espanha
# </a>
# <a class="games-slug" href="/football/leagues/spain/primera-division-women">
# Primeira Divisão
# </a>
# <span class="games-total">1</span>
# <button class="games-toggle"></button>
# </div>
# <div class="game" data-game-date="1648893600" data-game-id="610c80976d92df505b618192" data-tournament-id="5c9dfcf399bab86aec4aa713">
# <span class="game-info">
# <span class="match-status__sign sign--f">
# T
# </span>
# <span class="match-status__date">02/04/22</span>
# <span class="time-display">07:00</span>
# </span>
# <a class="teams" href="                /football/game/fc-barcelona-villarreal-cf-2022-04-03
#             ">
# <span class="team" data-host-id="5c9e01b099bab823ad7709af">
# <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
# <span class="team-name">Barcelona (Feminino)</span>
# <span class="count color-accent--green">6</span>
# </span>
# <span class="team" data-guest-id="610c8078c021bc6c6d631602">
# <img alt="Villarreal CF" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/198d13cbe4c85428ce01445f207b0efb32fb6575a5c536f0e69b7321cd4efabf.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
# <span class="team-name">Villarreal CF</span>
# <span class="count">1</span>
# </span>
# </a>
# <span class="match-status__col">
# <span class="result-form result-form--win"></span>
# </span>
# </div>
# </section>
# <section class="games resultsContainer" data-league="uefa-champions-league-women" data-tournament-id="5c9e01ae99bab82358173476">
# <div class="games-header" data-league="uefa-champions-league-women">
# <a class="v-flags__link" href="/football/leagues/europe">
# <img alt="Europa" class="lazy img expand-list__img img--size-s" data-src="/build/img/europe.cbdbaecc.svg" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# </a>
# <a class="games-cat" href="/football/leagues/europe">
# Europa
# </a>
# <a class="games-slug" href="/football/leagues/europe/uefa-champions-league-women">
# Liga dos Campeões UEFA, Feminino
# </a>
# <span class="games-total">1</span>
# <button class="games-toggle"></button>
# </div>
# <div class="game" data-game-date="1648658700" data-game-id="61c07e55d5055f45685133f6" data-tournament-id="5c9e01ae99bab82358173476">
# <span class="game-info">
# <span class="match-status__sign sign--f">
# T
# </span>
# <span class="match-status__date">30/03/22</span>
# <span class="time-display">13:45</span>
# </span>
# <a class="teams" href="                /football/game/fc-barcelona-real-madrid-2022-03-30
#             ">
# <span class="team" data-host-id="5c9e01b099bab823ad7709af">
# <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
# <span class="team-name">Barcelona (Feminino)</span>
# <span class="count color-accent--green">5</span>
# </span>
# <span class="team" data-guest-id="5d02106828f5fb5c655e27b6">
# <img alt="Real Madrid (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/28da681ebc411e994b39bf4be509ee9138d2504b66207b0c7eda9c9861350889.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
# <span class="team-name">Real Madrid (Feminino)</span>
# <span class="count">2</span>
# </span>
# </a>
# <span class="match-status__col">
# <span class="result-form result-form--win"></span>
# </span>
# </div>
# </section>
# <section class="games resultsContainer" data-league="primera-division-women" data-tournament-id="5c9dfcf399bab86aec4aa713">
# <div class="games-header" data-league="primera-division-women">
# <a class="v-flags__link" href="/football/leagues/spain">
# <img alt="Espanha" class="lazy img expand-list__img img--size-s" data-src="https://sportcdns.live/resized/72/72/category/56760aeeaa0c103030709a7ba43262e431bc2b44d5d53a4b165f1973f3749e50.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# </a>
# <a class="games-cat" href="/football/leagues/spain">
# Espanha
# </a>
# <a class="games-slug" href="/football/leagues/spain/primera-division-women">
# Primeira Divisão
# </a>
# <span class="games-total">1</span>
# <button class="games-toggle"></button>
# </div>
# <div class="game" data-game-date="1648292400" data-game-id="610c8096994bdd145f288269" data-tournament-id="5c9dfcf399bab86aec4aa713">
# <span class="game-info">
# <span class="match-status__sign sign--f">
# T
# </span>
# <span class="match-status__date">26/03/22</span>
# <span class="time-display">08:00</span>
# </span>
# <a class="teams" href="                /football/game/madrid-ccf-fc-barcelona-2022-03-27
#             ">
# <span class="team" data-host-id="5c9e045899bab8599602b94e">
# ...
# <span class="list-title list-title--black list-title--size-14 list-title--bold">Primeira Divisão</span>
# <span class="list-title list-title--gray list-title--size-12"></span>
# </a>
# </li>
# <li class="league-info__item">
# <a class="league-info__link" href="/football/leagues/europe/uefa-champions-league-women">
# <img alt="Liga dos Campeões UEFA, Feminino" class="lazy img league-info__img img--size-xl" data-src="https://sportcdns.live/resized/112/112/tournament/c1567ed851e96c9f4571f18269e28d4738b8d99d8fe22ba21a290653b5993b81.png" height="112" src="data:image/svg+xml;base64,..." width="112"/>
# <span class="list-title list-title--black list-title--size-14 list-title--bold">Liga dos Campeões UEFA, Feminino</span>
# <span class="list-title list-title--gray list-title--size-12"></span>
# </a>
# </li>
# <li class="league-info__item">
# <a class="league-info__link" href="/football/leagues/spain/supercup-women">
# <img alt="Supertaça de Espanha, Feminino" class="lazy img league-info__img img--size-xl" data-src="data:image/svg+xml;base64,..." height="112" src="data:image/svg+xml;base64,..." width="112"/>
# <span class="list-title list-title--black list-title--size-14 list-title--bold">Supertaça de Espanha, Feminino</span>
# <span class="list-title list-title--gray list-title--size-12"></span>
# </a>
# </li>
# <div></div>
# </ul>
# </div>
# </div>
# <div class="bn bn-slot--right-center">
# <div data-b="" id="1785212842"></div>
# </div> </section>
# </div>
# </main>
# <aside class="aside-right">
# <div class="bn bn-slot--right">
# <div data-s="" id="1589058776"></div>
# </div>
# </aside>
# </div>
# <footer class="footer">
# <div class="container">
# <section class="description">
# <a class="site-logo footer__logo" href="https://azscore.com.br/">
# <img alt="brand-logo" height="32" src="https://azscore.com.br/build/img/site-logo.5d8215cd.svg" width="134"/>
# </a>
# <p class="footer__description">
# Resultados ao vivo de futebol no placar ao vivo Azscore tem cobertura ao vivo de mais de 500 ligas de futebol, copas e torneios em todo o mundo com resultados atualizados ao vivo, estatísticas, tabelas de classificação, destaques em vídeo, jogos e transmissão ao vivo. As partidas ao vivo de todas as ligas de futebol têm atualizações rápidas e precisas para minutos, resultados, resultados de futebol de meio período e tempo integral, marcadores e assistentes, cartões, substituições, estatísticas de jogos e transmissão ao vivo.
# </p>
# </section>
# <section class="live-matches"><span class="footer__heading">Jogos ao vivo</span>
# <nav class="footer__nav menu-live-matches">
# <ul>
# <li>
# <a class="footer__link" href="                                   https://azscore.com.br/football/game/talant-bishkek-alay-2022-04-02
#                                    ">
# 45’
# Talant Bishkek
# 0
# -1
# Alay
# </a>
# </li>
# <li>
# <a class="footer__link" href="                                   https://azscore.com.br/football/game/orduspor-1967-mardin-fosfat-spor-2022-03-27
#                                    ">
# 76’
# Orduspor 1967
# 2
# -0
# Mardin Fosfat Spor
# </a>
# </li>
# <li>
# <a class="footer__link" href="                                   https://azscore.com.br/football/game/cosenza-calcio-parma-calcio-2022-04-02
#                                    ">
# 38’
# Cosenza Calcio
# 0
# -1
# Parma
# </a>
# </li>
# <li>
# <a class="footer__link" href="                                   https://azscore.com.br/football/game/fc-dinamo-minsk-fk-arsenal-dzerzhinsk-2022-04-02
#                                    ">
# 38’
# Dinamo de Minsk
# 0
# -0
# Arsenal Dzerzhinsk
# </a>
# </li>
# <li>
# <a class="footer__link" href="                                   https://azscore.com.br/football/game/fk-dukla-prague-sk-lisen-brno-2022-04-09
#                                    ">
# 9’
# Dukla Praga
# 0
# -1
# Lisen
# </a>
# </li>
# <li>
# <a class="footer__link" href="                                   https://azscore.com.br/football/game/big-bullets-ekwendeni-hammers-2022-04-02
#                                    ">
# 9’
# Big Bullets
# 0
# -0
# Ekwendeni Hammers
# </a>
# </li>
# </ul>
# </nav>
# </section>
# <section class="nearest-matches"><span class="footer__heading">Partidas mais próximas</span>
# <nav class="footer__nav menu-nearest-matches">
# <ul>
# <li>
# <a class="footer__link" href="                                   https://azscore.com.br/football/game/fc-zurich-fc-aarau-2022-04-02
#                                    ">
# FC Zurique (Feminino)
# - FC Aarau (Women)
# 11:00
# </a>
# </li>
# <li>
# <a class="footer__link" href="                                   https://azscore.com.br/football/game/nk-brezice-1919-nafta-1903-lendava-2022-04-03
#                                    ">
# Brezice
# - NK Nafta Lendava
# 11:00
# </a>
# </li>
# <li>
# <a class="footer__link" href="                                   https://azscore.com.br/football/game/afc-hornchurch-bognor-regis-town-2022-04-02
#                                    ">
# Hornchurch
# - Bognor Regis Town
# 11:00
# </a>
# </li>
# <li>
# <a class="footer__link" href="                                   https://azscore.com.br/football/game/nsi-runavik-ii-tb-tvoeroyri-2022-04-02
#                                    ">
# NSI Runavik II
# - TB Tvoroyri
# 11:30
# </a>
# </li>
# <li>
# <a class="footer__link" href="                                   https://azscore.com.br/football/game/ursl-vise-sint-eloois-winkel-2022-04-02
#                                    ">
# URSL Vise
# - Sint-Eloois-Winkel
# 15:00
# </a>
# </li>
# <li>
# <a class="footer__link" href="                                   https://azscore.com.br/football/game/columbus-crew-nashville-sc-2022-04-02
#                                    ">
# Columbus Crew
# - Nashville SC
# 19:00
# </a>
# </li>
# </ul>
# </nav>
# </section>
# <section class="feature-matches"><span class="footer__heading">Futuro</span>
# <nav class="footer__nav menu-feature">
# <ul>
# <li><a class="footer__link" href="                                   https://azscore.com.br/football/game/sv-meppen-msv-duisburg-2022-04-03
#                                    ">
# Meppen (Feminino)
# - MSV Duisburg (Feminino)
# 03/04/2022 09:00
# </a>
# </li>
# <li><a class="footer__link" href="                                   https://azscore.com.br/football/game/ringkobing-if-odder-igf-2022-04-03
#                                    ">
# Ringkobing
# - Odder IGF
# 03/04/2022 09:00
# </a>
# </li>
# <li><a class="footer__link" href="                                   https://azscore.com.br/football/game/fc-cska-1948-pfc-lokomotiv-plovdiv-2022-04-02
#                                    ">
# CSKA 1948
# - Lokomotiv Plovdiv
# 03/04/2022 09:15
# </a>
# </li>
# <li><a class="footer__link" href="                                   https://azscore.com.br/football/game/teramo-calcio-carrarese-calcio-2022-04-03
#                                    ">
# Teramo
# - Carrarese Calcio
# 03/04/2022 09:30
# </a>
# </li>
# <li><a class="footer__link" href="                                   https://azscore.com.br/football/game/ska-rostov-on-don-fc-dynamo-makhachkala-2022-04-03
#                                    ">
# SKA Rostov-on-Don
# - FC Dynamo-Makhachkala
# 03/04/2022 09:30
# </a>
# </li>
# <li><a class="footer__link" href="                                   https://azscore.com.br/football/game/black-leopards-jomo-cosmos-fc-2022-04-03
#                                    ">
# Black Leopards FC
# - Jomo Cosmos FC
# 03/04/2022 10:00
# </a>
# </li>
# </ul>
# </nav>
# </section>
# <section class="explore-site">
# </section>
# <section class="labels">
# <span class="labels__item">
# <img alt="" height="24" src="/build/img/labels/all/18+_gray.7e59346d.svg" width="71"/>
# </span>
# <a class="labels__item" href="https://www.gamblingtherapy.org/" rel="nofollow" target="_blank">
# <img alt="" height="24" src="/build/img/labels/all/gt_gray.3b4f34c1.svg" width="29"/>
# </a>
# </section>
# <section class="footer__bottom-info"><p class="footer__copy">© 2001-2022 azscore.com.br
# - Direito autoral</p>
# <nav class="footer__bottom-nav">
# <a class="footer__link" href="https://azscore.com.br/policy">Política de privacidade e cookies</a>
# <a class="footer__link" href="https://azscore.com.br/about">Sobre o Projeto</a>
# <a class="footer__link" href="https://azscore.com.br/contacts">Contatos</a>
# <a class="footer__link" href="https://azscore.com.br/football/widget">Widget</a>
# </nav>
# </section>
# </div>
# <button class="back-to-top"></button>
# </footer>
# <div class="bn bn-slot--catfish" hidden="">
# <a class="bn__close" href="#"></a>
# <div class="bn-slot__content">
# <div data-b="" id="1999066823"></div>
# </div>
# </div>
# </div>
# <span class="page-info-data" data-my-games="" data-sort-order=" league ">
# </span>
# <script defer="" src="/js/jsCalendar.js?v=1" type="6afa614c93024545cb6f87ea-text/javascript"></script>
# <script defer="" type="6afa614c93024545cb6f87ea-text/javascript">
#     document.calendar_shortDays = [
#         "Dom",
#         "Seg",
#         "Ter",
#         "Qua",
#         "Qui",
#         "Sex",
#         "Sáb"
#     ];
#
#     (function () {
#
#         // Get library
#         var jsCalendar = window.jsCalendar;
#
#         // If jsCalendar is not loaded
#         if (typeof jsCalendar === 'undefined') {
#             // If there is no language to load array
#             if (typeof window.jsCalendar_language2load === 'undefined') {
#                 window.jsCalendar_language2load = [];
#             }
#             // Wrapper to add language to load list
#             jsCalendar = {
#                 addLanguage: function (language) {
#                     // Add language to load list
#                     window.jsCalendar_language2load.push(language);
#                 }
#             };
#         }
#
#         // Add a new language
#         jsCalendar.addLanguage({
#             // Language code
#             code: 'pt',
#             // Months of the year
#             months: [
#                 "Janeiro ",
#                 "Fevereiro",
#                 "Marcha",
#                 "Abril",
#                 "Pode",
#                 "Junho",
#                 "Julho",
#                 "Agosto",
#                 "Setembro",
#                 "Outubro",
#                 "Novembro",
#                 "Dezembro"
#             ],
#             // Days of the week
#             days: [
#               "Dom",
#               "Seg",
#               "Ter",
#               "Qua",
#               "Qui",
#               "Sex",
#               "Sáb"
#             ]
#         });
#
#     })();
# </script>
# <script defer="" src="/build/runtime.420770e4.js" type="6afa614c93024545cb6f87ea-text/javascript"></script>
# <script defer="" src="/build/0.fe223400.js" type="6afa614c93024545cb6f87ea-text/javascript"></script>
# <script defer="" src="/build/1.904ddf13.js" type="6afa614c93024545cb6f87ea-text/javascript"></script>
# <script defer="" src="/build/app.bdc468a0.js" type="6afa614c93024545cb6f87ea-text/javascript"></script>
# <script defer="" src="/build/desktop.f1579b9b.js" type="6afa614c93024545cb6f87ea-text/javascript"></script>
# <script defer="" src="/build/odds.3b50a7a5.js" type="6afa614c93024545cb6f87ea-text/javascript"></script>
# <script data-cfasync="false">
# !function(l,o,e,c){l[c]=l[c]||function(){(l[c+"l"]=l[c+"l"]||[]).push(arguments)};var t=o.getElementsByTagName(e)[0],i=o.createElement(e);i.async=!0,i.setAttribute("data-cfasync","false"),i.src="//sl1.cdn.bescore.com/uploads/media/3/7/17273/v1/viewability.min.js",t.parentNode.insertBefore(i,t);var a=!1,r=o.querySelectorAll("[data-b]");if(r.length)for(var d=r.length-1;0<=d;d--)l[c](r[d].id,{id:r[d].id}),r[d].dataset.zid?y(r[d]):r[d].dataset.catfish&&function(r){var d=1,n=setInterval(function(){var e,t,i,a;d<=4?(zid=d%2==0?r.id:r.dataset.catfish,e=(1e17*Math.random()).toString(36),(t=o.createElement("div")).id=e,o.body.appendChild(t),i=o.querySelectorAll("div[data-nopop]"),a=!1,i.forEach(function(e){e.id||(a=e)}),a&&a.parentNode.removeChild(a),l[c](e,{id:zid}),d++):clearInterval(n)},4e4)}(r[d]);var n=o.querySelectorAll("[data-odds]");if(n.length)for(d=n.length-1;0<=d;d--)l[c](n[d].id,{id:n[d].id});var s,v=o.querySelector("[data-pops]");v&&((s=function(e){var t=localStorage.getItem(e);if(!t)return null;var i=JSON.parse(t);if(Date.now()>i.expiry)return localStorage.removeItem(e),null;return i}("ABN_DEEP_VIEW"))?(s.value+=1,2<=s.value&&l[c](v.id,{id:v.id}),f("ABN_DEEP_VIEW",s.value,s.expiry,!0)):f("ABN_DEEP_VIEW",1,30));var u=o.querySelector("[data-br-bg]");function f(e,t,i,a){a=a||!1;var r=Date.now(),d={value:t,expiry:a?i:r+60*i*1e3};localStorage.setItem(e,JSON.stringify(d))}function y(i){var a=1,e=setInterval(function(){a<=4?(zid=a%2==0?i.id:i.dataset.zid,(new OpenAdViewability).checkViewability(i,function(e){var t;e.viewabiltyStatus&&(t=(1e17*Math.random()).toString(36),i.innerHTML='<div id="'+t+'"></div>',l[c](t,{id:zid}),a++)})):clearInterval(e)},3e4)}u&&1280<=l.innerWidth&&(l[c](u.id,{id:u.id}),a=!0),l.ABNsideAds=l.ABNsideAds||function(){var e=o.querySelectorAll("[data-s]");if(e.length)for(var t=e.length-1;0<=t;t--)l[c](e[t].id,{id:e[t].id}),a=!0,e[t].dataset.zid&&y(e[t])},l.addEventListener("resize",function(){1280<=l.innerWidth&&u&&!a&&(l[c](u.id,{id:u.id}),a=!0)},!1)}(window,document,"script","ABNS");
# </script>
# <script type="6afa614c93024545cb6f87ea-text/javascript">
#       const APP_ROUTE = "team.scores"
#       const APP_LOCALE = "pt";
#       const APP_MERCURE_HUB_URL = "https://sportmercure.live/.well-known/mercure";
#       //const APP_MERCURE_HUB_URL = 'http://127.0.0.1:8080/.well-known/mercure';
#       const IMG_DOMAIN = "https://sportcdns.live/resized/";
#       const TRANSLATIONS = {
#         "cancelled": "Canc.",
#         "finished": "T",
#         "halftime": "INT",
#         "live": "Ao vivo",
#         "postponed": "Adiado",
#         "abandoned": "Prem.",
#         "aet": "TI/TE",
#         "closed": "match.block.state.finished",
#         "ended": "match.block.state.ended",
#         "not_started": "Não iniciados",
#         "retired": "match.block.state.retired",
#         "penalty_shootout": "Penalidades",
#         "period_start": "match.main_event.period_start",
#         "period_start1": "1 ª Metade",
#         "period_start1_overtime": "1º Tempo Extra",
#         "period_start2": "2ª Parte",
#         "period_start2_overtime": "2º Tempo Extra",
#         "assist": "Assistência",
#         "playerOut": "Fora",
#         "regular_period_1": "1 ª Metade",
#         "regular_period_2": "2ª Parte",
#         "overtime_1": "1º Tempo Extra",
#         "overtime_2": "2º Tempo Extra",
#         "penalties": "Penalidades",
#       };
#     </script>
# <script type="6afa614c93024545cb6f87ea-text/javascript">
#   if ('serviceWorker' in navigator) {
#     window.addEventListener('load', function () {
#       navigator.serviceWorker.register('/sw-test.js').then(response => {
#         if(response.active) {
#           response.active.postMessage({
#             url: response.scope
#           })
#         }
#       });
#
#       navigator.serviceWorker.addEventListener("message", e => {
#         //window.location = e.data.url;
#         console.log(`redirect to ${e.data.url}`);
#       });
#     });
#   }
#
# </script>
# <script type="6afa614c93024545cb6f87ea-text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.eu01.nr-data.net","licenseKey":"NRJS-2cbb0d1fc536d8d929f","applicationID":"57231449,57229053","transactionName":"MhBSZQoZXksCBRFRDQtacVIMEV9WTBIAWQ9LBlNeCh1D","queueTime":0,"applicationTime":56,"atts":"HldRE0IDTUU=","errorBeacon":"bam.eu01.nr-data.net","agent":""}</script><script data-cf-settings="6afa614c93024545cb6f87ea-|49" defer="" src="/cdn-cgi/scripts/7d0fa10a/cloudflare-static/rocket-loader.min.js"></script><script type="text/javascript">(function(){window['__CF$cv$params']={r:'6f59a49339323565',m:'3xlcWhMO57cWguXXz0L6Ff.kOpXAz9YA46yIA9u8aBQ-1648903329-0-AfniOQ8z2uBf+6Qaz178V9Xy2D9y49ykSkkkx6qCEk3hVsG2GvfyKBhTkbCpX57xLryn3rEP/M2tK2NrcZ1nE/qdcsLeAsRk8X6pS2E6wRF4ytk+Bt5lFoVj2odJLxPzfG248VVWKsOavO6dG1RS+lMbO1tH6c9jj1gQLzq4dtSU',s:[0xb3601afe18,0xdf8c812d82],}})();</script><script crossorigin="anonymous" data-cf-beacon='{"rayId":"6f59a49339323565","token":"8054503e918d43bca4103e520940b8f3","version":"2021.12.0","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194"></script>
# </body>
# </html>

# %%
results = soup.findAll('section', attrs={'class': re.compile('resultsContainer')})

# %%
def has_data_src(tag):
    return tag.has_attr('data-src')

# %%
for tag in results:
    if 'data-src' in tag.attrs:
        print(tag)

# %%
# 10 competitions are displayed on the page
len(results)
# Out:
# 10

# %%
for competition in results:
    for tag in competition:
        print(type(tag))
        print(tag)
        print('hump')
    break
# Out:
# <class 'bs4.element.NavigableString'>
#
#
# hump
# <class 'bs4.element.Tag'>
# <div class="games-header" data-league="primera-division-women">
# <a class="v-flags__link" href="/football/leagues/spain">
# <img alt="Espanha" class="lazy img expand-list__img img--size-s" data-src="https://sportcdns.live/resized/72/72/category/56760aeeaa0c103030709a7ba43262e431bc2b44d5d53a4b165f1973f3749e50.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
# </a>
# <a class="games-cat" href="/football/leagues/spain">
# Espanha
# </a>
# <a class="games-slug" href="/football/leagues/spain/primera-division-women">
# Primeira Divisão
# </a>
# <span class="games-total">1</span>
# <button class="games-toggle"></button>
# </div>
# hump
# <class 'bs4.element.NavigableString'>
#
#
# hump
# <class 'bs4.element.Tag'>
# <div class="game" data-game-date="1648893600" data-game-id="610c80976d92df505b618192" data-tournament-id="5c9dfcf399bab86aec4aa713">
# <span class="game-info">
# <span class="match-status__sign sign--f">
# T
# </span>
# <span class="match-status__date">02/04/22</span>
# <span class="time-display">07:00</span>
# </span>
# <a class="teams" href="                /football/game/fc-barcelona-villarreal-cf-2022-04-03
#             ">
# <span class="team" data-host-id="5c9e01b099bab823ad7709af">
# <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
# <span class="team-name">Barcelona (Feminino)</span>
# <span class="count color-accent--green">6</span>
# </span>
# <span class="team" data-guest-id="610c8078c021bc6c6d631602">
# <img alt="Villarreal CF" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/198d13cbe4c85428ce01445f207b0efb32fb6575a5c536f0e69b7321cd4efabf.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
# <span class="team-name">Villarreal CF</span>
# <span class="count">1</span>
# </span>
# </a>
# <span class="match-status__col">
# <span class="result-form result-form--win"></span>
# </span>
# </div>
# hump
# <class 'bs4.element.NavigableString'>
#
#
# hump

# %%
results
# Out:
# [<section class="games resultsContainer" data-league="primera-division-women" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <div class="games-header" data-league="primera-division-women">
#  <a class="v-flags__link" href="/football/leagues/spain">
#  <img alt="Espanha" class="lazy img expand-list__img img--size-s" data-src="https://sportcdns.live/resized/72/72/category/56760aeeaa0c103030709a7ba43262e431bc2b44d5d53a4b165f1973f3749e50.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
#  </a>
#  <a class="games-cat" href="/football/leagues/spain">
#  Espanha
#  </a>
#  <a class="games-slug" href="/football/leagues/spain/primera-division-women">
#  Primeira Divisão
#  </a>
#  <span class="games-total">1</span>
#  <button class="games-toggle"></button>
#  </div>
#  <div class="game" data-game-date="1648893600" data-game-id="610c80976d92df505b618192" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">02/04/22</span>
#  <span class="time-display">07:00</span>
#  </span>
#  <a class="teams" href="                /football/game/fc-barcelona-villarreal-cf-2022-04-03
#              ">
#  <span class="team" data-host-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">6</span>
#  </span>
#  <span class="team" data-guest-id="610c8078c021bc6c6d631602">
#  <img alt="Villarreal CF" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/198d13cbe4c85428ce01445f207b0efb32fb6575a5c536f0e69b7321cd4efabf.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Villarreal CF</span>
#  <span class="count">1</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  </section>,
#  <section class="games resultsContainer" data-league="uefa-champions-league-women" data-tournament-id="5c9e01ae99bab82358173476">
#  <div class="games-header" data-league="uefa-champions-league-women">
#  <a class="v-flags__link" href="/football/leagues/europe">
#  <img alt="Europa" class="lazy img expand-list__img img--size-s" data-src="/build/img/europe.cbdbaecc.svg" height="72" src="data:image/svg+xml;base64,..." width="72"/>
#  </a>
#  <a class="games-cat" href="/football/leagues/europe">
#  Europa
#  </a>
#  <a class="games-slug" href="/football/leagues/europe/uefa-champions-league-women">
#  Liga dos Campeões UEFA, Feminino
#  </a>
#  <span class="games-total">1</span>
#  <button class="games-toggle"></button>
#  </div>
#  <div class="game" data-game-date="1648658700" data-game-id="61c07e55d5055f45685133f6" data-tournament-id="5c9e01ae99bab82358173476">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">30/03/22</span>
#  <span class="time-display">13:45</span>
#  </span>
#  <a class="teams" href="                /football/game/fc-barcelona-real-madrid-2022-03-30
#              ">
#  <span class="team" data-host-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">5</span>
#  </span>
#  <span class="team" data-guest-id="5d02106828f5fb5c655e27b6">
#  <img alt="Real Madrid (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/28da681ebc411e994b39bf4be509ee9138d2504b66207b0c7eda9c9861350889.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Real Madrid (Feminino)</span>
#  <span class="count">2</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  </section>,
#  <section class="games resultsContainer" data-league="primera-division-women" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <div class="games-header" data-league="primera-division-women">
#  <a class="v-flags__link" href="/football/leagues/spain">
#  <img alt="Espanha" class="lazy img expand-list__img img--size-s" data-src="https://sportcdns.live/resized/72/72/category/56760aeeaa0c103030709a7ba43262e431bc2b44d5d53a4b165f1973f3749e50.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
#  </a>
#  <a class="games-cat" href="/football/leagues/spain">
#  Espanha
#  </a>
#  <a class="games-slug" href="/football/leagues/spain/primera-division-women">
#  Primeira Divisão
#  </a>
#  <span class="games-total">1</span>
#  <button class="games-toggle"></button>
#  </div>
#  <div class="game" data-game-date="1648292400" data-game-id="610c8096994bdd145f288269" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">26/03/22</span>
#  <span class="time-display">08:00</span>
#  </span>
#  <a class="teams" href="                /football/game/madrid-ccf-fc-barcelona-2022-03-27
#              ">
#  <span class="team" data-host-id="5c9e045899bab8599602b94e">
#  <img alt="Madrid (feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/48a6b5c34b782f476d6fcbba837ed41f7c78062391a4ee56e4fa91b46c6df906.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Madrid (feminino)</span>
#  <span class="count">1</span>
#  </span>
#  <span class="team" data-guest-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">2</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  </section>,
#  <section class="games resultsContainer" data-league="uefa-champions-league-women" data-tournament-id="5c9e01ae99bab82358173476">
#  <div class="games-header" data-league="uefa-champions-league-women">
#  <a class="v-flags__link" href="/football/leagues/europe">
#  <img alt="Europa" class="lazy img expand-list__img img--size-s" data-src="/build/img/europe.cbdbaecc.svg" height="72" src="data:image/svg+xml;base64,..." width="72"/>
#  </a>
#  <a class="games-cat" href="/football/leagues/europe">
#  Europa
#  </a>
#  <a class="games-slug" href="/football/leagues/europe/uefa-champions-league-women">
#  Liga dos Campeões UEFA, Feminino
#  </a>
#  <span class="games-total">1</span>
#  <button class="games-toggle"></button>
#  </div>
#  <div class="game" data-game-date="1647979200" data-game-id="61c07e558b6b7f47fb462962" data-tournament-id="5c9e01ae99bab82358173476">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">22/03/22</span>
#  <span class="time-display">17:00</span>
#  </span>
#  <a class="teams" href="                /football/game/real-madrid-fc-barcelona-2022-03-22
#              ">
#  <span class="team" data-host-id="5d02106828f5fb5c655e27b6">
#  <img alt="Real Madrid (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/28da681ebc411e994b39bf4be509ee9138d2504b66207b0c7eda9c9861350889.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Real Madrid (Feminino)</span>
#  <span class="count">1</span>
#  </span>
#  <span class="team" data-guest-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">3</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  </section>,
#  <section class="games resultsContainer" data-league="copa-de-sm-la-reina" data-tournament-id="5c9dfd5699bab8764f67b7ee">
#  <div class="games-header" data-league="copa-de-sm-la-reina">
#  <a class="v-flags__link" href="/football/leagues/spain">
#  <img alt="Espanha" class="lazy img expand-list__img img--size-s" data-src="https://sportcdns.live/resized/72/72/category/56760aeeaa0c103030709a7ba43262e431bc2b44d5d53a4b165f1973f3749e50.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
#  </a>
#  <a class="games-cat" href="/football/leagues/spain">
#  Espanha
#  </a>
#  <a class="games-slug" href="/football/leagues/spain/copa-de-sm-la-reina">
#  Taça de SM La Reina
#  </a>
#  <span class="games-total">1</span>
#  <button class="games-toggle"></button>
#  </div>
#  <div class="game" data-game-date="1647459900" data-game-id="6225c8e15856b524432c91f2" data-tournament-id="5c9dfd5699bab8764f67b7ee">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">16/03/22</span>
#  <span class="time-display">16:45</span>
#  </span>
#  <a class="teams" href="                /football/game/real-sociedad-san-sebastian-fc-barcelona-2022-03-16
#              ">
#  <span class="team" data-host-id="5c9e045099bab85721675294">
#  <img alt="Real Sociedad (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/3937aaaee0ad3d2fba56ef638082d6d556f73156054d446cebbf17a60d0d3c40.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Real Sociedad (Feminino)</span>
#  <span class="count">0</span>
#  </span>
#  <span class="team" data-guest-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">3</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  </section>,
#  <section class="games resultsContainer" data-league="primera-division-women" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <div class="games-header" data-league="primera-division-women">
#  <a class="v-flags__link" href="/football/leagues/spain">
#  <img alt="Espanha" class="lazy img expand-list__img img--size-s" data-src="https://sportcdns.live/resized/72/72/category/56760aeeaa0c103030709a7ba43262e431bc2b44d5d53a4b165f1973f3749e50.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
#  </a>
#  <a class="games-cat" href="/football/leagues/spain">
#  Espanha
#  </a>
#  <a class="games-slug" href="/football/leagues/spain/primera-division-women">
#  Primeira Divisão
#  </a>
#  <span class="games-total">2</span>
#  <button class="games-toggle"></button>
#  </div>
#  <div class="game" data-game-date="1647169200" data-game-id="610c809578f9be2eaa3c3926" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">13/03/22</span>
#  <span class="time-display">08:00</span>
#  </span>
#  <a class="teams" href="                /football/game/fc-barcelona-real-madrid-2022-03-13
#              ">
#  <span class="team" data-host-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">5</span>
#  </span>
#  <span class="team" data-guest-id="5d02106828f5fb5c655e27b6">
#  <img alt="Real Madrid (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/28da681ebc411e994b39bf4be509ee9138d2504b66207b0c7eda9c9861350889.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Real Madrid (Feminino)</span>
#  <span class="count">0</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  <div class="game" data-game-date="1646564400" data-game-id="610c809483ba952d7e7beaff" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">06/03/22</span>
#  <span class="time-display">08:00</span>
#  </span>
#  <a class="teams" href="                /football/game/deportivo-alaves-fc-barcelona-2022-03-06
#              ">
#  <span class="team" data-host-id="610c80779885d93b4f5e9834">
#  <img alt="Deportivo Alaves (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/63ccaece4dedcba1274ac478362afc89bdf2349679ebbd4b50a1cb6228d7f9e6.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Deportivo Alaves (Feminino)</span>
#  <span class="count">0</span>
#  </span>
#  <span class="team" data-guest-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">6</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  </section>,
#  <section class="games resultsContainer" data-league="copa-de-sm-la-reina" data-tournament-id="5c9dfd5699bab8764f67b7ee">
#  <div class="games-header" data-league="copa-de-sm-la-reina">
#  <a class="v-flags__link" href="/football/leagues/spain">
#  <img alt="Espanha" class="lazy img expand-list__img img--size-s" data-src="https://sportcdns.live/resized/72/72/category/56760aeeaa0c103030709a7ba43262e431bc2b44d5d53a4b165f1973f3749e50.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
#  </a>
#  <a class="games-cat" href="/football/leagues/spain">
#  Espanha
#  </a>
#  <a class="games-slug" href="/football/leagues/spain/copa-de-sm-la-reina">
#  Taça de SM La Reina
#  </a>
#  <span class="games-total">1</span>
#  <button class="games-toggle"></button>
#  </div>
#  <div class="game" data-game-date="1646233200" data-game-id="620710d425a656730937dd92" data-tournament-id="5c9dfd5699bab8764f67b7ee">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">02/03/22</span>
#  <span class="time-display">12:00</span>
#  </span>
#  <a class="teams" href="                /football/game/rayo-vallecano-fc-barcelona-2022-03-02
#              ">
#  <span class="team" data-host-id="5c9e045199bab8594e6adefb">
#  <img alt="Rayo Vallecano (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/481b0cd3432c8c767da98b9d0deebe97be96c4fce0fcc8653fbc5a2865533115.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Rayo Vallecano (Feminino)</span>
#  <span class="count">1</span>
#  </span>
#  <span class="team" data-guest-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">3</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  </section>,
#  <section class="games resultsContainer" data-league="primera-division-women" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <div class="games-header" data-league="primera-division-women">
#  <a class="v-flags__link" href="/football/leagues/spain">
#  <img alt="Espanha" class="lazy img expand-list__img img--size-s" data-src="https://sportcdns.live/resized/72/72/category/56760aeeaa0c103030709a7ba43262e431bc2b44d5d53a4b165f1973f3749e50.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
#  </a>
#  <a class="games-cat" href="/football/leagues/spain">
#  Espanha
#  </a>
#  <a class="games-slug" href="/football/leagues/spain/primera-division-women">
#  Primeira Divisão
#  </a>
#  <span class="games-total">6</span>
#  <button class="games-toggle"></button>
#  </div>
#  <div class="game" data-game-date="1644750000" data-game-id="610c809220022e75fe557db5" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">13/02/22</span>
#  <span class="time-display">08:00</span>
#  </span>
#  <a class="teams" href="                /football/game/athletic-bilbao-fc-barcelona-2022-02-13
#              ">
#  <span class="team" data-host-id="5c9e044f99bab85721675292">
#  <img alt="Athletic Bilbao (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/c35e7627fc9114a38b90c1c2ef009c9755b8dc32ecb6203cc37c032dd30c6dd6.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Athletic Bilbao (Feminino)</span>
#  <span class="count">0</span>
#  </span>
#  <span class="team" data-guest-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">3</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  <div class="game" data-game-date="1644422400" data-game-id="61fdcc23fa7bb678be631d92" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">09/02/22</span>
#  <span class="time-display">13:00</span>
#  </span>
#  <a class="teams" href="                /football/game/real-sociedad-san-sebastian-fc-barcelona-2022-02-09
#              ">
#  <span class="team" data-host-id="5c9e045099bab85721675294">
#  <img alt="Real Sociedad (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/3937aaaee0ad3d2fba56ef638082d6d556f73156054d446cebbf17a60d0d3c40.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Real Sociedad (Feminino)</span>
#  <span class="count">1</span>
#  </span>
#  <span class="team" data-guest-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">9</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  <div class="game" data-game-date="1644145200" data-game-id="610c80908ab6bb46be386d97" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">06/02/22</span>
#  <span class="time-display">08:00</span>
#  </span>
#  <a class="teams" href="                /football/game/fc-barcelona-sd-eibar-2022-02-06
#              ">
#  <span class="team" data-host-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">7</span>
#  </span>
#  <span class="team" data-guest-id="5f642448e310095601128a74">
#  <img alt="Eibar (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/07e677db30dc62fc1b3f1056d7449d3ef47bdef9a31cf6423ddb6fffffc977bf.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Eibar (Feminino)</span>
#  <span class="count">0</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  <div class="game" data-game-date="1643817600" data-game-id="610c808f0ac1bd50db5a3841" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">02/02/22</span>
#  <span class="time-display">13:00</span>
#  </span>
#  <a class="teams" href="                /football/game/levante-ud-fc-barcelona-2022-02-02
#              ">
#  <span class="team" data-host-id="5c9e044799bab8594e6adef3">
#  <img alt="Levante (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/33cfde008db09a5fdb0b920cba72cf6411bb497666d1ca1cd81c54937c113a29.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Levante (Feminino)</span>
#  <span class="count">1</span>
#  </span>
#  <span class="team" data-guest-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">4</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  <div class="game" data-game-date="1643536800" data-game-id="61f338b89f6d3e562e6bf372" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">30/01/22</span>
#  <span class="time-display">07:00</span>
#  </span>
#  <a class="teams" href="                /football/game/barcelona-women-real-betis-women-2022-01-30
#              ">
#  <span class="team" data-host-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count">0</span>
#  </span>
#  <span class="team" data-guest-id="5c9e044e99bab855a7190cd2">
#  <img alt="Real Betis (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/35140be9b1b6e5ecfde7365393d266f1aa59fb2862b70f17174716453baad5ad.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Real Betis (Feminino)</span>
#  <span class="count">0</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--draw"></span>
#  </span>
#  </div>
#  <div class="game" data-game-date="1643454000" data-game-id="610c808d4c485304bc410774" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">29/01/22</span>
#  <span class="time-display">08:00</span>
#  </span>
#  <a class="teams" href="                /football/game/fc-barcelona-real-betis-sevilla-2022-01-30
#              ">
#  <span class="team" data-host-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">4</span>
#  </span>
#  <span class="team" data-guest-id="5c9e044e99bab855a7190cd2">
#  <img alt="Real Betis (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/35140be9b1b6e5ecfde7365393d266f1aa59fb2862b70f17174716453baad5ad.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Real Betis (Feminino)</span>
#  <span class="count">0</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  </section>,
#  <section class="games resultsContainer" data-league="supercup-women" data-tournament-id="5e38a622884fcb278b50c4c2">
#  <div class="games-header" data-league="supercup-women">
#  <a class="v-flags__link" href="/football/leagues/spain">
#  <img alt="Espanha" class="lazy img expand-list__img img--size-s" data-src="https://sportcdns.live/resized/72/72/category/56760aeeaa0c103030709a7ba43262e431bc2b44d5d53a4b165f1973f3749e50.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
#  </a>
#  <a class="games-cat" href="/football/leagues/spain">
#  Espanha
#  </a>
#  <a class="games-slug" href="/football/leagues/spain/supercup-women">
#  Supertaça de Espanha, Feminino
#  </a>
#  <span class="games-total">2</span>
#  <button class="games-toggle"></button>
#  </div>
#  <div class="game" data-game-date="1642935600" data-game-id="61ea91816c206c43a21a2593" data-tournament-id="5e38a622884fcb278b50c4c2">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">23/01/22</span>
#  <span class="time-display">08:00</span>
#  </span>
#  <a class="teams" href="                /football/game/fc-barcelona-atletico-madrid-2022-01-23
#              ">
#  <span class="team" data-host-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">7</span>
#  </span>
#  <span class="team" data-guest-id="5c9e01bd99bab824752e06f1">
#  <img alt="Atlético de Madrid (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/c78a4ccaa612585f1794c08627daadc0ae7317010834bdd0443b8fd86088649e.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Atlético de Madrid (Feminino)</span>
#  <span class="count">0</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  <div class="game" data-game-date="1642616100" data-game-id="61e034da54be5b7ee91e4142" data-tournament-id="5e38a622884fcb278b50c4c2">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">19/01/22</span>
#  <span class="time-display">15:15</span>
#  </span>
#  <a class="teams" href="                /football/game/fc-barcelona-real-madrid-2022-01-19
#              ">
#  <span class="team" data-host-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">1</span>
#  </span>
#  <span class="team" data-guest-id="5d02106828f5fb5c655e27b6">
#  <img alt="Real Madrid (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/28da681ebc411e994b39bf4be509ee9138d2504b66207b0c7eda9c9861350889.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Real Madrid (Feminino)</span>
#  <span class="count">0</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  </section>,
#  <section class="games resultsContainer" data-league="primera-division-women" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <div class="games-header" data-league="primera-division-women">
#  <a class="v-flags__link" href="/football/leagues/spain">
#  <img alt="Espanha" class="lazy img expand-list__img img--size-s" data-src="https://sportcdns.live/resized/72/72/category/56760aeeaa0c103030709a7ba43262e431bc2b44d5d53a4b165f1973f3749e50.png" height="72" src="data:image/svg+xml;base64,..." width="72"/>
#  </a>
#  <a class="games-cat" href="/football/leagues/spain">
#  Espanha
#  </a>
#  <a class="games-slug" href="/football/leagues/spain/primera-division-women">
#  Primeira Divisão
#  </a>
#  <span class="games-total">4</span>
#  <button class="games-toggle"></button>
#  </div>
#  <div class="game" data-game-date="1642003200" data-game-id="610c808b723b907fbf00e6c1" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">12/01/22</span>
#  <span class="time-display">13:00</span>
#  </span>
#  <a class="teams" href="                /football/game/fc-barcelona-sporting-de-huelva-2022-01-12
#              ">
#  <span class="team" data-host-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">5</span>
#  </span>
#  <span class="team" data-guest-id="5ca5e72799bab80ca841909f">
#  <img alt="Sporting de Huelva (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/c371e95a2fe900643b5e77699b4269e2f382e1dec086f63cab95890d642c606e.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Sporting de Huelva (Feminino)</span>
#  <span class="count">0</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  <div class="game" data-game-date="1641657600" data-game-id="610c808af1969227951ae483" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">08/01/22</span>
#  <span class="time-display">13:00</span>
#  </span>
#  <a class="teams" href="                /football/game/udg-tenerife-fc-barcelona-2022-01-09
#              ">
#  <span class="team" data-host-id="5c9e1d1299bab8357809df53">
#  <img alt="UD Granadilla Tenerife Sur (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/48efd753e2112b6e93581f677d565b66c3b627363679f9a1732d12016c5c527f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">UD Granadilla Tenerife Sur (Feminino)</span>
#  <span class="count">0</span>
#  </span>
#  <span class="team" data-guest-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">7</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  <div class="game" data-game-date="1640188800" data-game-id="610c80897bbb2c7bf301337d" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">22/12/21</span>
#  <span class="time-display">13:00</span>
#  </span>
#  <a class="teams" href="                /football/game/fc-barcelona-madrid-ccf-2021-12-22
#              ">
#  <span class="team" data-host-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">7</span>
#  </span>
#  <span class="team" data-guest-id="5c9e045899bab8599602b94e">
#  <img alt="Madrid (feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/48a6b5c34b782f476d6fcbba837ed41f7c78062391a4ee56e4fa91b46c6df906.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Madrid (feminino)</span>
#  <span class="count">0</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  <div class="game" data-game-date="1639825200" data-game-id="610c80889b27c64fff3b0d6f" data-tournament-id="5c9dfcf399bab86aec4aa713">
#  <span class="game-info">
#  <span class="match-status__sign sign--f">
#  T
#  </span>
#  <span class="match-status__date">18/12/21</span>
#  <span class="time-display">08:00</span>
#  </span>
#  <a class="teams" href="                /football/game/fc-barcelona-rayo-vallecano-2021-12-19
#              ">
#  <span class="team" data-host-id="5c9e01b099bab823ad7709af">
#  <img alt="Barcelona (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/8e0ad92c92da8df70a19088e0ae4228c71561147c08980a7d157a2488795e25f.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Barcelona (Feminino)</span>
#  <span class="count color-accent--green">4</span>
#  </span>
#  <span class="team" data-guest-id="5c9e045199bab8594e6adefb">
#  <img alt="Rayo Vallecano (Feminino)" class="lazy team-img" data-src="https://sportcdns.live/resized/40/40/team/481b0cd3432c8c767da98b9d0deebe97be96c4fce0fcc8653fbc5a2865533115.png" height="40" src="data:image/svg+xml;base64,..." width="40"/>
#  <span class="team-name">Rayo Vallecano (Feminino)</span>
#  <span class="count">0</span>
#  </span>
#  </a>
#  <span class="match-status__col">
#  <span class="result-form result-form--win"></span>
#  </span>
#  </div>
#  </section>]
